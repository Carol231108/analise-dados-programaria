# %% [markdown]
# #Introdução

# %% [markdown]
# #Importações

# %%
#importações
import pandas as pd
from google.colab import drive

# %%
from google.colab import drive

# %%
#Montando o drive
drive.mount("/content/drive")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
#Lendo os dados
dados = pd.read_excel("/content/drive/MyDrive/Curso PrograMaria/planilha_modulo3 (1).xlsx")

# %% [markdown]
# ## Uso da biblioteca Pandas

# %%
dados.head(10)
# Out:
#    Unnamed: 0                                ID  IDADE FAIXA IDADE     GENERO  \
# 0           0  zzqzz3l9ily8nuo2m7wyzzqzz3w48o96   39.0       35-39  Masculino
# 1           1  zzls2oftfn9law393oezzls2ofhvfpzd   32.0       30-34  Masculino
# 2           2  zzdwqzfqqp1ypc7ps6m0hzzdwqz292yi   53.0       50-54  Masculino
# 3           3  zzbqh3uy7yk7k9qmkzzbqtb4s9faqspl   27.0       25-29  Masculino
# 4           4  zzaf1m95yan929rb94wzzaf1mekhvhpg   46.0       45-49   Feminino
# 5           5  zz0nlhbd8oxyiyxzz0nlh7g4xkiaza5v   32.0       30-34   Feminino
# 6           6  zytlxsdgalh22cgrijvzytlxa49i8yzx   21.0       17-21  Masculino
# 7           7  zyc0twzno2sm5or5ovoxzyc0twz0300d   31.0       30-34   Feminino
# 8           8  zy4o5dk6iuxpdwgzy4o58xvd6ykwohrj   33.0       30-34  Masculino
# 9           9  zxc3d314cn1c2ovmzxc34ha7nkw1na3j    NaN         55+   Feminino
#
#   COR/RACA/ETNIA  PCD               EXPERIENCIA_PROFISSIONAL_PREJUDICADA  \
# 0          Parda  Não  Não acredito que minha experiência profissiona...
# 1          Parda  Não  Sim, acredito que a minha a experiência profis...
# 2         Branca  Não                                                NaN
# 3         Branca  Não                                                NaN
# 4         Branca  Não  Não acredito que minha experiência profissiona...
# 5          Parda  Não  Não acredito que minha experiência profissiona...
# 6          Parda  Não  Não acredito que minha experiência profissiona...
# 7         Branca  Não  Não acredito que minha experiência profissiona...
# 8         Branca  Não                                                NaN
# 9          Parda  Não  Não acredito que minha experiência profissiona...
#
#                           ASPECTOS_PREJUDICADOS  VIVE_NO_BRASIL  ...  \
# 0                                           NaN            True  ...
# 1  Aprovação em processos seletivos/entrevistas            True  ...
# 2                                           NaN            True  ...
# 3                                           NaN            True  ...
# 4                                           NaN            True  ...
# 5                                           NaN            True  ...
# 6                                           NaN            True  ...
# 7                                           NaN            True  ...
# 8                                           NaN            True  ...
# 9                                           NaN            True  ...
#
#                             SETOR NUMERO DE FUNCIONARIOS GESTOR?  \
# 0                   Setor Público         Acima de 3.000     0.0
# 1                     Outra Opção         Acima de 3.000     1.0
# 2              Finanças ou Bancos         Acima de 3.000     0.0
# 3                Setor Automotivo         Acima de 3.000     0.0
# 4                   Setor Público           de 101 a 500     0.0
# 5                        Educação         Acima de 3.000     0.0
# 6              Finanças ou Bancos         Acima de 3.000     0.0
# 7  Tecnologia/Fábrica de Software              de 6 a 10     0.0
# 8  Tecnologia/Fábrica de Software         Acima de 3.000     0.0
# 9                        Educação         Acima de 3.000     0.0
#
#         CARGO COMO GESTOR                                        CARGO ATUAL  \
# 0                     NaN                DBA/Administrador de Banco de Dados
# 1  Supervisor/Coordenador                                                NaN
# 2                     NaN  Desenvolvedor/ Engenheiro de Software/ Analist...
# 3                     NaN                  Cientista de Dados/Data Scientist
# 4                     NaN  Desenvolvedor/ Engenheiro de Software/ Analist...
# 5                     NaN                                          Professor
# 6                     NaN                          Analista de BI/BI Analyst
# 7                     NaN  Desenvolvedor/ Engenheiro de Software/ Analist...
# 8                     NaN                          Analista de BI/BI Analyst
# 9                     NaN                                          Professor
#
#     NIVEL                    FAIXA SALARIAL  \
# 0  Júnior   de R$ 8.001/mês a R$ 12.000/mês
# 1     NaN    de R$ 4.001/mês a R$ 6.000/mês
# 2   Pleno  de R$ 12.001/mês a R$ 16.000/mês
# 3  Sênior  de R$ 12.001/mês a R$ 16.000/mês
# 4   Pleno    de R$ 6.001/mês a R$ 8.000/mês
# 5   Pleno    de R$ 2.001/mês a R$ 3.000/mês
# 6  Júnior    de R$ 4.001/mês a R$ 6.000/mês
# 7  Júnior    de R$ 2.001/mês a R$ 3.000/mês
# 8  Sênior    de R$ 6.001/mês a R$ 8.000/mês
# 9   Pleno   de R$ 8.001/mês a R$ 12.000/mês
#
#   QUANTO TEMPO DE EXPERIÊNCIA NA ÁREA DE DADOS VOCÊ TEM?  \
# 0                                      de 1 a 2 anos
# 1                                      de 3 a 4 anos
# 2                                      de 3 a 4 anos
# 3                                      de 4 a 6 anos
# 4             Não tenho experiência na área de dados
# 5             Não tenho experiência na área de dados
# 6                                      de 1 a 2 anos
# 7                                     Menos de 1 ano
# 8                                     Menos de 1 ano
# 9                                    Mais de 10 anos
#
#   QUANTO TEMPO DE EXPERIÊNCIA NA ÁREA DE TI/ENGENHARIA DE SOFTWARE VOCÊ TEVE ANTES DE COMEÇAR A TRABALHAR NA ÁREA DE DADOS?  \
# 0                                     de 7 a 10 anos
# 1                                     Menos de 1 ano
# 2                                    Mais de 10 anos
# 3  Não tive experiência na área de TI/Engenharia ...
# 4                                    Mais de 10 anos
# 5  Não tive experiência na área de TI/Engenharia ...
# 6                                     Menos de 1 ano
# 7                                     Menos de 1 ano
# 8  Não tive experiência na área de TI/Engenharia ...
# 9  Não tive experiência na área de TI/Engenharia ...
#
#    SALARIO
# 0  11194.0
# 1   4695.0
# 2  14202.0
# 3  15463.0
# 4   7733.0
# 5   2336.0
# 6   4491.0
# 7   2704.0
# 8   7112.0
# 9  10822.0
#
# [10 rows x 28 columns]

# %%
dados - pd

# %%
dados.tail()
# Out:
#       Unnamed: 0                                ID  IDADE FAIXA IDADE  \
# 4266        4266  01jnrn9f6va0menfhk2ztm01jnrn96bp   26.0       25-29
# 4267        4267  01dyfxam4u4bi29fem01dyfxaq9akvqp   30.0       30-34
# 4268        4268  00zw9ks9d40z4u00zz3d20iix65qpli3   29.0       25-29
# 4269        4269  00xu7yujd7s57emj00xu7y0c3njix3de    NaN       17-21
# 4270        4270  00lb35llmdsidpa00lb35qcdysnzvhv7   24.0       22-24
#
#          GENERO COR/RACA/ETNIA  PCD  \
# 4266  Masculino         Branca  Não
# 4267   Feminino         Branca  Não
# 4268  Masculino         Branca  Não
# 4269  Masculino         Branca  Não
# 4270  Masculino         Branca  Não
#
#                    EXPERIENCIA_PROFISSIONAL_PREJUDICADA ASPECTOS_PREJUDICADOS  \
# 4266                                                NaN                   NaN
# 4267  Não acredito que minha experiência profissiona...                   NaN
# 4268                                                NaN                   NaN
# 4269                                                NaN                   NaN
# 4270                                                NaN                   NaN
#
#       VIVE_NO_BRASIL  ...                                SETOR  \
# 4266            True  ...       Tecnologia/Fábrica de Software
# 4267            True  ...                  Área de Consultoria
# 4268            True  ...  Setor Imobiliário/ Construção Civil
# 4269            True  ...                            Indústria
# 4270            True  ...                         Agronegócios
#
#      NUMERO DE FUNCIONARIOS GESTOR?  CARGO COMO GESTOR  \
# 4266         Acima de 3.000     0.0                NaN
# 4267            de 51 a 100     0.0                NaN
# 4268           de 101 a 500     1.0       Gerente/Head
# 4269       de 1.001 a 3.000     0.0                NaN
# 4270         de 501 a 1.000     0.0                NaN
#
#                                             CARGO ATUAL   NIVEL  \
# 4266                     Analista de Dados/Data Analyst   Pleno
# 4267  Engenheiro de Dados/Arquiteto de Dados/Data En...   Pleno
# 4268                                                NaN     NaN
# 4269                                        Outra Opção  Júnior
# 4270                     Analista de Dados/Data Analyst  Júnior
#
#                         FAIXA SALARIAL  \
# 4266    de R$ 4.001/mês a R$ 6.000/mês
# 4267    de R$ 3.001/mês a R$ 4.000/mês
# 4268  de R$ 16.001/mês a R$ 20.000/mês
# 4269             Menos de R$ 1.000/mês
# 4270    de R$ 3.001/mês a R$ 4.000/mês
#
#      QUANTO TEMPO DE EXPERIÊNCIA NA ÁREA DE DADOS VOCÊ TEM?  \
# 4266                                      de 3 a 4 anos
# 4267                                      de 1 a 2 anos
# 4268                                      de 4 a 6 anos
# 4269                                     Menos de 1 ano
# 4270                                      de 1 a 2 anos
#
#      QUANTO TEMPO DE EXPERIÊNCIA NA ÁREA DE TI/ENGENHARIA DE SOFTWARE VOCÊ TEVE ANTES DE COMEÇAR A TRABALHAR NA ÁREA DE DADOS?  \
# 4266                                     de 7 a 10 anos
# 4267  Não tive experiência na área de TI/Engenharia ...
# 4268  Não tive experiência na área de TI/Engenharia ...
# 4269  Não tive experiência na área de TI/Engenharia ...
# 4270  Não tive experiência na área de TI/Engenharia ...
#
#       SALARIO
# 4266   4329.0
# 4267   3758.0
# 4268  19607.0
# 4269    989.0
# 4270   3079.0
#
# [5 rows x 28 columns]

# %%
dados.shape
# Out:
# (4271, 28)

# %%
len(dados)
# Out:
# 4271

# %%
dados.columns
# Out:
# Index(['Unnamed: 0', 'ID', 'IDADE', 'FAIXA IDADE', 'GENERO', 'COR/RACA/ETNIA',
#        'PCD', 'EXPERIENCIA_PROFISSIONAL_PREJUDICADA', 'ASPECTOS_PREJUDICADOS',
#        'VIVE_NO_BRASIL', 'ESTADO ONDE MORA', 'UF ONDE MORA',
#        'REGIAO ONDE MORA', 'MUDOU DE ESTADO?', 'REGIAO DE ORIGEM',
#        'NIVEL DE ENSINO', 'ÁREA DE FORMAÇÃO',
#        'QUAL SUA SITUAÇÃO ATUAL DE TRABALHO?', 'SETOR',
#        'NUMERO DE FUNCIONARIOS', 'GESTOR?', 'CARGO COMO GESTOR', 'CARGO ATUAL',
#        'NIVEL', 'FAIXA SALARIAL',
#        'QUANTO TEMPO DE EXPERIÊNCIA NA ÁREA DE DADOS VOCÊ TEM?',
#        'QUANTO TEMPO DE EXPERIÊNCIA NA ÁREA DE TI/ENGENHARIA DE SOFTWARE VOCÊ TEVE ANTES DE COMEÇAR A TRABALHAR NA ÁREA DE DADOS?',
#        'SALARIO'],
#       dtype='object')

# %%
dados.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4271 entries, 0 to 4270
# Data columns (total 28 columns):
#  #   Column                                                                                                                     Non-Null Count  Dtype
# ---  ------                                                                                                                     --------------  -----
#  0   Unnamed: 0                                                                                                                 4271 non-null   int64
#  1   ID                                                                                                                         4271 non-null   object
#  2   IDADE                                                                                                                      4197 non-null   float64
#  3   FAIXA IDADE                                                                                                                4271 non-null   object
#  4   GENERO                                                                                                                     4262 non-null   object
#  5   COR/RACA/ETNIA                                                                                                             4271 non-null   object
#  6   PCD                                                                                                                        4271 non-null   object
#  7   EXPERIENCIA_PROFISSIONAL_PREJUDICADA                                                                                       2190 non-null   object
#  8   ASPECTOS_PREJUDICADOS                                                                                                      837 non-null    object
#  9   VIVE_NO_BRASIL                                                                                                             4271 non-null   bool
#  10  ESTADO ONDE MORA                                                                                                           4156 non-null   object
#  11  UF ONDE MORA                                                                                                               4156 non-null   object
#  12  REGIAO ONDE MORA                                                                                                           4171 non-null   object
#  13  MUDOU DE ESTADO?                                                                                                           4171 non-null   float64
#  14  REGIAO DE ORIGEM                                                                                                           772 non-null    object
#  15  NIVEL DE ENSINO                                                                                                            4271 non-null   object
#  16  ÁREA DE FORMAÇÃO                                                                                                           4149 non-null   object
#  17  QUAL SUA SITUAÇÃO ATUAL DE TRABALHO?                                                                                       4271 non-null   object
#  18  SETOR                                                                                                                      3694 non-null   object
#  19  NUMERO DE FUNCIONARIOS                                                                                                     3694 non-null   object
#  20  GESTOR?                                                                                                                    3694 non-null   float64
#  21  CARGO COMO GESTOR                                                                                                          713 non-null    object
#  22  CARGO ATUAL                                                                                                                2981 non-null   object
#  23  NIVEL                                                                                                                      2981 non-null   object
#  24  FAIXA SALARIAL                                                                                                             3694 non-null   object
#  25  QUANTO TEMPO DE EXPERIÊNCIA NA ÁREA DE DADOS VOCÊ TEM?                                                                     3694 non-null   object
#  26  QUANTO TEMPO DE EXPERIÊNCIA NA ÁREA DE TI/ENGENHARIA DE SOFTWARE VOCÊ TEVE ANTES DE COMEÇAR A TRABALHAR NA ÁREA DE DADOS?  3694 non-null   object
#  27  SALARIO                                                                                                                    3694 non-null   float64
# dtypes: bool(1), float64(4), int64(1), object(22)
# memory usage: 905.2+ KB

# %% [markdown]
# # Repetindo analise do excel

# %%
dados.columns
# Out:
# Index(['Unnamed: 0', 'ID', 'IDADE', 'FAIXA IDADE', 'GENERO', 'COR/RACA/ETNIA',
#        'PCD', 'EXPERIENCIA_PROFISSIONAL_PREJUDICADA', 'ASPECTOS_PREJUDICADOS',
#        'VIVE_NO_BRASIL', 'ESTADO ONDE MORA', 'UF ONDE MORA',
#        'REGIAO ONDE MORA', 'MUDOU DE ESTADO?', 'REGIAO DE ORIGEM',
#        'NIVEL DE ENSINO', 'ÁREA DE FORMAÇÃO',
#        'QUAL SUA SITUAÇÃO ATUAL DE TRABALHO?', 'SETOR',
#        'NUMERO DE FUNCIONARIOS', 'GESTOR?', 'CARGO COMO GESTOR', 'CARGO ATUAL',
#        'NIVEL', 'FAIXA SALARIAL',
#        'QUANTO TEMPO DE EXPERIÊNCIA NA ÁREA DE DADOS VOCÊ TEM?',
#        'QUANTO TEMPO DE EXPERIÊNCIA NA ÁREA DE TI/ENGENHARIA DE SOFTWARE VOCÊ TEVE ANTES DE COMEÇAR A TRABALHAR NA ÁREA DE DADOS?',
#        'SALARIO'],
#       dtype='object')

# %%
dados[dados['GENERO']== "Feminino"]
# Out:
#       Unnamed: 0                                ID  IDADE FAIXA IDADE  \
# 4              4  zzaf1m95yan929rb94wzzaf1mekhvhpg   46.0       45-49
# 5              5  zz0nlhbd8oxyiyxzz0nlh7g4xkiaza5v   32.0       30-34
# 7              7  zyc0twzno2sm5or5ovoxzyc0twz0300d   31.0       30-34
# 9              9  zxc3d314cn1c2ovmzxc34ha7nkw1na3j    NaN         55+
# 10            10  zwy34gktg0tfjq2ttjvazwy34gg3g49i   25.0       25-29
# ...          ...                               ...    ...         ...
# 4248        4248  070o4zayoboztox764qu070o4zafbqrd   27.0       25-29
# 4251        4251  068hhicrqggu068huq0l2ab3g7liagy8   34.0       30-34
# 4258        4258  03zjgijmnwv9qrlzbr03zjgij1eae1hw   25.0       25-29
# 4259        4259  03n2lq8st9zobnowu3w03n2lqi0flz2w   28.0       25-29
# 4267        4267  01dyfxam4u4bi29fem01dyfxaq9akvqp   30.0       30-34
#
#         GENERO COR/RACA/ETNIA  PCD  \
# 4     Feminino         Branca  Não
# 5     Feminino          Parda  Não
# 7     Feminino         Branca  Não
# 9     Feminino          Parda  Não
# 10    Feminino          Parda  Não
# ...        ...            ...  ...
# 4248  Feminino         Branca  Não
# 4251  Feminino          Preta  Não
# 4258  Feminino         Branca  Não
# 4259  Feminino         Branca  Não
# 4267  Feminino         Branca  Não
#
#                    EXPERIENCIA_PROFISSIONAL_PREJUDICADA  \
# 4     Não acredito que minha experiência profissiona...
# 5     Não acredito que minha experiência profissiona...
# 7     Não acredito que minha experiência profissiona...
# 9     Não acredito que minha experiência profissiona...
# 10    Não acredito que minha experiência profissiona...
# ...                                                 ...
# 4248  Não acredito que minha experiência profissiona...
# 4251  Não acredito que minha experiência profissiona...
# 4258  Sim, acredito que a minha a experiência profis...
# 4259  Sim, acredito que a minha a experiência profis...
# 4267  Não acredito que minha experiência profissiona...
#
#                                   ASPECTOS_PREJUDICADOS  VIVE_NO_BRASIL  ...  \
# 4                                                   NaN            True  ...
# 5                                                   NaN            True  ...
# 7                                                   NaN            True  ...
# 9                                                   NaN            True  ...
# 10                                                  NaN            True  ...
# ...                                                 ...             ...  ...
# 4248                                                NaN            True  ...
# 4251                                                NaN            True  ...
# 4258  Senioridade das vagas recebidas em relação à s...            True  ...
# 4259  Relação com outros membros da empresa, em mome...            True  ...
# 4267                                                NaN            True  ...
#
#                                SETOR NUMERO DE FUNCIONARIOS GESTOR?  \
# 4                      Setor Público           de 101 a 500     0.0
# 5                           Educação         Acima de 3.000     0.0
# 7     Tecnologia/Fábrica de Software              de 6 a 10     0.0
# 9                           Educação         Acima de 3.000     0.0
# 10                            Varejo           de 101 a 500     0.0
# ...                              ...                    ...     ...
# 4248              Finanças ou Bancos           de 101 a 500     0.0
# 4251              Finanças ou Bancos       de 1.001 a 3.000     0.0
# 4258                             NaN                    NaN     NaN
# 4259              Finanças ou Bancos         Acima de 3.000     1.0
# 4267             Área de Consultoria            de 51 a 100     0.0
#
#            CARGO COMO GESTOR  \
# 4                        NaN
# 5                        NaN
# 7                        NaN
# 9                        NaN
# 10                       NaN
# ...                      ...
# 4248                     NaN
# 4251                     NaN
# 4258                     NaN
# 4259  Supervisor/Coordenador
# 4267                     NaN
#
#                                             CARGO ATUAL   NIVEL  \
# 4     Desenvolvedor/ Engenheiro de Software/ Analist...   Pleno
# 5                                             Professor   Pleno
# 7     Desenvolvedor/ Engenheiro de Software/ Analist...  Júnior
# 9                                             Professor   Pleno
# 10                            Analista de BI/BI Analyst  Júnior
# ...                                                 ...     ...
# 4248                  Cientista de Dados/Data Scientist   Pleno
# 4251  Engenheiro de Dados/Arquiteto de Dados/Data En...   Pleno
# 4258                                                NaN     NaN
# 4259                                                NaN     NaN
# 4267  Engenheiro de Dados/Arquiteto de Dados/Data En...   Pleno
#
#                         FAIXA SALARIAL  \
# 4       de R$ 6.001/mês a R$ 8.000/mês
# 5       de R$ 2.001/mês a R$ 3.000/mês
# 7       de R$ 2.001/mês a R$ 3.000/mês
# 9      de R$ 8.001/mês a R$ 12.000/mês
# 10      de R$ 3.001/mês a R$ 4.000/mês
# ...                                ...
# 4248    de R$ 4.001/mês a R$ 6.000/mês
# 4251    de R$ 4.001/mês a R$ 6.000/mês
# 4258                               NaN
# 4259  de R$ 20.001/mês a R$ 25.000/mês
# 4267    de R$ 3.001/mês a R$ 4.000/mês
#
#      QUANTO TEMPO DE EXPERIÊNCIA NA ÁREA DE DADOS VOCÊ TEM?  \
# 4                Não tenho experiência na área de dados
# 5                Não tenho experiência na área de dados
# 7                                        Menos de 1 ano
# 9                                       Mais de 10 anos
# 10                                       Menos de 1 ano
# ...                                                 ...
# 4248                                      de 1 a 2 anos
# 4251                                     Menos de 1 ano
# 4258                                                NaN
# 4259                                      de 4 a 6 anos
# 4267                                      de 1 a 2 anos
#
#      QUANTO TEMPO DE EXPERIÊNCIA NA ÁREA DE TI/ENGENHARIA DE SOFTWARE VOCÊ TEVE ANTES DE COMEÇAR A TRABALHAR NA ÁREA DE DADOS?  \
# 4                                       Mais de 10 anos
# 5     Não tive experiência na área de TI/Engenharia ...
# 7                                        Menos de 1 ano
# 9     Não tive experiência na área de TI/Engenharia ...
# 10    Não tive experiência na área de TI/Engenharia ...
# ...                                                 ...
# 4248  Não tive experiência na área de TI/Engenharia ...
# 4251                                     Menos de 1 ano
# 4258                                                NaN
# 4259  Não tive experiência na área de TI/Engenharia ...
# 4267  Não tive experiência na área de TI/Engenharia ...
#
#       SALARIO
# 4      7733.0
# 5      2336.0
# 7      2704.0
# 9     10822.0
# 10     3450.0
# ...       ...
# 4248   4781.0
# 4251   5673.0
# 4258      NaN
# 4259  24963.0
# 4267   3758.0
#
# [1056 rows x 28 columns]

# %%
dados[dados["GENERO"]!="Masculino"]
# Out:
#       Unnamed: 0                                ID  IDADE FAIXA IDADE  \
# 4              4  zzaf1m95yan929rb94wzzaf1mekhvhpg   46.0       45-49
# 5              5  zz0nlhbd8oxyiyxzz0nlh7g4xkiaza5v   32.0       30-34
# 7              7  zyc0twzno2sm5or5ovoxzyc0twz0300d   31.0       30-34
# 9              9  zxc3d314cn1c2ovmzxc34ha7nkw1na3j    NaN         55+
# 10            10  zwy34gktg0tfjq2ttjvazwy34gg3g49i   25.0       25-29
# ...          ...                               ...    ...         ...
# 4248        4248  070o4zayoboztox764qu070o4zafbqrd   27.0       25-29
# 4251        4251  068hhicrqggu068huq0l2ab3g7liagy8   34.0       30-34
# 4258        4258  03zjgijmnwv9qrlzbr03zjgij1eae1hw   25.0       25-29
# 4259        4259  03n2lq8st9zobnowu3w03n2lqi0flz2w   28.0       25-29
# 4267        4267  01dyfxam4u4bi29fem01dyfxaq9akvqp   30.0       30-34
#
#         GENERO COR/RACA/ETNIA  PCD  \
# 4     Feminino         Branca  Não
# 5     Feminino          Parda  Não
# 7     Feminino         Branca  Não
# 9     Feminino          Parda  Não
# 10    Feminino          Parda  Não
# ...        ...            ...  ...
# 4248  Feminino         Branca  Não
# 4251  Feminino          Preta  Não
# 4258  Feminino         Branca  Não
# 4259  Feminino         Branca  Não
# 4267  Feminino         Branca  Não
#
#                    EXPERIENCIA_PROFISSIONAL_PREJUDICADA  \
# 4     Não acredito que minha experiência profissiona...
# 5     Não acredito que minha experiência profissiona...
# 7     Não acredito que minha experiência profissiona...
# 9     Não acredito que minha experiência profissiona...
# 10    Não acredito que minha experiência profissiona...
# ...                                                 ...
# 4248  Não acredito que minha experiência profissiona...
# 4251  Não acredito que minha experiência profissiona...
# 4258  Sim, acredito que a minha a experiência profis...
# 4259  Sim, acredito que a minha a experiência profis...
# 4267  Não acredito que minha experiência profissiona...
#
#                                   ASPECTOS_PREJUDICADOS  VIVE_NO_BRASIL  ...  \
# 4                                                   NaN            True  ...
# 5                                                   NaN            True  ...
# 7                                                   NaN            True  ...
# 9                                                   NaN            True  ...
# 10                                                  NaN            True  ...
# ...                                                 ...             ...  ...
# 4248                                                NaN            True  ...
# 4251                                                NaN            True  ...
# 4258  Senioridade das vagas recebidas em relação à s...            True  ...
# 4259  Relação com outros membros da empresa, em mome...            True  ...
# 4267                                                NaN            True  ...
#
#                                SETOR NUMERO DE FUNCIONARIOS GESTOR?  \
# 4                      Setor Público           de 101 a 500     0.0
# 5                           Educação         Acima de 3.000     0.0
# 7     Tecnologia/Fábrica de Software              de 6 a 10     0.0
# 9                           Educação         Acima de 3.000     0.0
# 10                            Varejo           de 101 a 500     0.0
# ...                              ...                    ...     ...
# 4248              Finanças ou Bancos           de 101 a 500     0.0
# 4251              Finanças ou Bancos       de 1.001 a 3.000     0.0
# 4258                             NaN                    NaN     NaN
# 4259              Finanças ou Bancos         Acima de 3.000     1.0
# 4267             Área de Consultoria            de 51 a 100     0.0
#
#            CARGO COMO GESTOR  \
# 4                        NaN
# 5                        NaN
# 7                        NaN
# 9                        NaN
# 10                       NaN
# ...                      ...
# 4248                     NaN
# 4251                     NaN
# 4258                     NaN
# 4259  Supervisor/Coordenador
# 4267                     NaN
#
#                                             CARGO ATUAL   NIVEL  \
# 4     Desenvolvedor/ Engenheiro de Software/ Analist...   Pleno
# 5                                             Professor   Pleno
# 7     Desenvolvedor/ Engenheiro de Software/ Analist...  Júnior
# 9                                             Professor   Pleno
# 10                            Analista de BI/BI Analyst  Júnior
# ...                                                 ...     ...
# 4248                  Cientista de Dados/Data Scientist   Pleno
# 4251  Engenheiro de Dados/Arquiteto de Dados/Data En...   Pleno
# 4258                                                NaN     NaN
# 4259                                                NaN     NaN
# 4267  Engenheiro de Dados/Arquiteto de Dados/Data En...   Pleno
#
#                         FAIXA SALARIAL  \
# 4       de R$ 6.001/mês a R$ 8.000/mês
# 5       de R$ 2.001/mês a R$ 3.000/mês
# 7       de R$ 2.001/mês a R$ 3.000/mês
# 9      de R$ 8.001/mês a R$ 12.000/mês
# 10      de R$ 3.001/mês a R$ 4.000/mês
# ...                                ...
# 4248    de R$ 4.001/mês a R$ 6.000/mês
# 4251    de R$ 4.001/mês a R$ 6.000/mês
# 4258                               NaN
# 4259  de R$ 20.001/mês a R$ 25.000/mês
# 4267    de R$ 3.001/mês a R$ 4.000/mês
#
#      QUANTO TEMPO DE EXPERIÊNCIA NA ÁREA DE DADOS VOCÊ TEM?  \
# 4                Não tenho experiência na área de dados
# 5                Não tenho experiência na área de dados
# 7                                        Menos de 1 ano
# 9                                       Mais de 10 anos
# 10                                       Menos de 1 ano
# ...                                                 ...
# 4248                                      de 1 a 2 anos
# 4251                                     Menos de 1 ano
# 4258                                                NaN
# 4259                                      de 4 a 6 anos
# 4267                                      de 1 a 2 anos
#
#      QUANTO TEMPO DE EXPERIÊNCIA NA ÁREA DE TI/ENGENHARIA DE SOFTWARE VOCÊ TEVE ANTES DE COMEÇAR A TRABALHAR NA ÁREA DE DADOS?  \
# 4                                       Mais de 10 anos
# 5     Não tive experiência na área de TI/Engenharia ...
# 7                                        Menos de 1 ano
# 9     Não tive experiência na área de TI/Engenharia ...
# 10    Não tive experiência na área de TI/Engenharia ...
# ...                                                 ...
# 4248  Não tive experiência na área de TI/Engenharia ...
# 4251                                     Menos de 1 ano
# 4258                                                NaN
# 4259  Não tive experiência na área de TI/Engenharia ...
# 4267  Não tive experiência na área de TI/Engenharia ...
#
#       SALARIO
# 4      7733.0
# 5      2336.0
# 7      2704.0
# 9     10822.0
# 10     3450.0
# ...       ...
# 4248   4781.0
# 4251   5673.0
# 4258      NaN
# 4259  24963.0
# 4267   3758.0
#
# [1077 rows x 28 columns]

# %%
dados[dados["GENERO"].str.contains("não", na=False)]
# Out:
#       Unnamed: 0                                ID  IDADE FAIXA IDADE  \
# 562          562  vhuw8xnpbmj6oh20xovhuwcbdl4a12ni   29.0       25-29
# 1528        1528  n2ktdn33istvlu1ha4v3kn2ktdn1rsp1    NaN         55+
# 1913        1913  k3as6jdh3w4jf4ztsw4kpkk3as6jdy19   30.0       30-34
# 1925        1925  jzppdwep2kpisqjjzppdh304v83cj7eu    NaN       17-21
# 2554        2554  f5l206z0hr9uh3nz2iiff5l206c0g10o   20.0       17-21
# 3090        3090  a6ugmsw7s8hu5aa6uglio5apj74fam9o   26.0       25-29
# 3357        3357  7q0icczxn0l3a894cbx7q0icczjyud0n   29.0       25-29
# 3493        3493  6m8haop6lxnaizpwij6m8haopiax98jg   25.0       25-29
# 3610        3610  5mloglozmr0r715mntaxbt6xy8b5olmb   30.0       30-34
# 4171        4171  0rksyxnqhn13nwytwi6y0rkssx6jmodf   26.0       25-29
# 4200        4200  0liu228yff8fnm3zeuahsx0liu228y07   28.0       25-29
# 4227        4227  0eqzo5w2l5wizswvwywt8h0eqzo5yucv   28.0       25-29
#
#                     GENERO        COR/RACA/ETNIA                   PCD  \
# 562   Prefiro não informar                 Parda                   Não
# 1528  Prefiro não informar              Indígena  Prefiro não informar
# 1913  Prefiro não informar  Prefiro não informar                   Não
# 1925  Prefiro não informar  Prefiro não informar  Prefiro não informar
# 2554  Prefiro não informar  Prefiro não informar                   Não
# 3090  Prefiro não informar                 Parda                   Não
# 3357  Prefiro não informar                 Preta                   Não
# 3493  Prefiro não informar                Branca                   Não
# 3610  Prefiro não informar                Branca                   Não
# 4171  Prefiro não informar                Branca                   Não
# 4200  Prefiro não informar                 Outra                   Não
# 4227  Prefiro não informar                 Preta                   Não
#
#                    EXPERIENCIA_PROFISSIONAL_PREJUDICADA  \
# 562   Sim, acredito que a minha a experiência profis...
# 1528  Não acredito que minha experiência profissiona...
# 1913  Não acredito que minha experiência profissiona...
# 1925  Sim, acredito que minha experiência profission...
# 2554  Não acredito que minha experiência profissiona...
# 3090  Não acredito que minha experiência profissiona...
# 3357  Não acredito que minha experiência profissiona...
# 3493  Sim, acredito que a minha a experiência profis...
# 3610  Sim, acredito que a minha a experiência profis...
# 4171  Não acredito que minha experiência profissiona...
# 4200  Não acredito que minha experiência profissiona...
# 4227  Sim, acredito que a minha a experiência profis...
#
#                                   ASPECTOS_PREJUDICADOS  VIVE_NO_BRASIL  ...  \
# 562   Atenção dada pelas pessoas diante das minhas o...            True  ...
# 1528                                                NaN            True  ...
# 1913                                                NaN            True  ...
# 1925  Quantidade de oportunidades de emprego/vagas r...           False  ...
# 2554                                                NaN            True  ...
# 3090                                                NaN            True  ...
# 3357                                                NaN            True  ...
# 3493  Quantidade de oportunidades de emprego/vagas r...            True  ...
# 3610               Velocidade de progressão de carreira            True  ...
# 4171                                                NaN            True  ...
# 4200                                                NaN            True  ...
# 4227  Atenção dada pelas pessoas diante das minhas o...            True  ...
#
#                                     SETOR NUMERO DE FUNCIONARIOS GESTOR?  \
# 562                                   NaN                    NaN     NaN
# 1528                        Setor Público            de 51 a 100     0.0
# 1913                          Outra Opção           de 101 a 500     0.0
# 1925                   Setor Farmaceutico               de 1 a 5     0.0
# 2554                        Setor Público         Acima de 3.000     0.0
# 3090                             Educação           de 101 a 500     1.0
# 3357       Tecnologia/Fábrica de Software       de 1.001 a 3.000     0.0
# 3493                   Finanças ou Bancos         Acima de 3.000     0.0
# 3610       Tecnologia/Fábrica de Software           de 101 a 500     0.0
# 4171                          Outra Opção       de 1.001 a 3.000     0.0
# 4200  Setor Imobiliário/ Construção Civil         de 501 a 1.000     1.0
# 4227                          Outra Opção         Acima de 3.000     0.0
#
#             CARGO COMO GESTOR  \
# 562                       NaN
# 1528                      NaN
# 1913                      NaN
# 1925                      NaN
# 2554                      NaN
# 3090  Team Leader/Tech Leader
# 3357                      NaN
# 3493                      NaN
# 3610                      NaN
# 4171                      NaN
# 4200  Team Leader/Tech Leader
# 4227                      NaN
#
#                                             CARGO ATUAL   NIVEL  \
# 562                                                 NaN     NaN
# 1528               Analista de Suporte/Analista Técnico  Júnior
# 1913                     Analista de Dados/Data Analyst   Pleno
# 1925                                        Outra Opção  Júnior
# 2554                  Cientista de Dados/Data Scientist  Júnior
# 3090                                                NaN     NaN
# 3357  Engenheiro de Dados/Arquiteto de Dados/Data En...  Júnior
# 3493                     Analista de Dados/Data Analyst   Pleno
# 3610  Engenheiro de Dados/Arquiteto de Dados/Data En...  Sênior
# 4171                     Analista de Dados/Data Analyst   Pleno
# 4200                                                NaN     NaN
# 4227  Product Manager/ Product Owner (PM/APM/DPM/GPM...   Pleno
#
#                         FAIXA SALARIAL  \
# 562                                NaN
# 1528             Menos de R$ 1.000/mês
# 1913   de R$ 8.001/mês a R$ 12.000/mês
# 1925    de R$ 2.001/mês a R$ 3.000/mês
# 2554    de R$ 1.001/mês a R$ 2.000/mês
# 3090   de R$ 8.001/mês a R$ 12.000/mês
# 3357    de R$ 6.001/mês a R$ 8.000/mês
# 3493    de R$ 3.001/mês a R$ 4.000/mês
# 3610   de R$ 8.001/mês a R$ 12.000/mês
# 4171   de R$ 8.001/mês a R$ 12.000/mês
# 4200  de R$ 16.001/mês a R$ 20.000/mês
# 4227    de R$ 6.001/mês a R$ 8.000/mês
#
#      QUANTO TEMPO DE EXPERIÊNCIA NA ÁREA DE DADOS VOCÊ TEM?  \
# 562                                                 NaN
# 1528                                     Menos de 1 ano
# 1913                                    Mais de 10 anos
# 1925                                      de 1 a 2 anos
# 2554                                      de 1 a 2 anos
# 3090                                      de 1 a 2 anos
# 3357                                     Menos de 1 ano
# 3493                                      de 3 a 4 anos
# 3610                                      de 3 a 4 anos
# 4171                                      de 1 a 2 anos
# 4200                                    Mais de 10 anos
# 4227                                     Menos de 1 ano
#
#      QUANTO TEMPO DE EXPERIÊNCIA NA ÁREA DE TI/ENGENHARIA DE SOFTWARE VOCÊ TEVE ANTES DE COMEÇAR A TRABALHAR NA ÁREA DE DADOS?  \
# 562                                                 NaN
# 1528                                     Menos de 1 ano
# 1913                                      de 3 a 4 anos
# 1925                                     Menos de 1 ano
# 2554                                      de 1 a 2 anos
# 3090  Não tive experiência na área de TI/Engenharia ...
# 3357  Não tive experiência na área de TI/Engenharia ...
# 3493                                     Menos de 1 ano
# 3610  Não tive experiência na área de TI/Engenharia ...
# 4171                                     Menos de 1 ano
# 4200                                     de 7 a 10 anos
# 4227  Não tive experiência na área de TI/Engenharia ...
#
#       SALARIO
# 562       NaN
# 1528    826.0
# 1913  11476.0
# 1925   2294.0
# 2554   1339.0
# 3090  11545.0
# 3357   6345.0
# 3493   3900.0
# 3610  10174.0
# 4171  10517.0
# 4200  18282.0
# 4227   7942.0
#
# [12 rows x 28 columns]

# %%
dados[dados["IDADE"]>30]
# Out:
#       Unnamed: 0                                ID  IDADE FAIXA IDADE  \
# 0              0  zzqzz3l9ily8nuo2m7wyzzqzz3w48o96   39.0       35-39
# 1              1  zzls2oftfn9law393oezzls2ofhvfpzd   32.0       30-34
# 2              2  zzdwqzfqqp1ypc7ps6m0hzzdwqz292yi   53.0       50-54
# 4              4  zzaf1m95yan929rb94wzzaf1mekhvhpg   46.0       45-49
# 5              5  zz0nlhbd8oxyiyxzz0nlh7g4xkiaza5v   32.0       30-34
# ...          ...                               ...    ...         ...
# 4257        4257  043snvbsxn3fuyfe043j5comuyu8g6ba   46.0       45-49
# 4260        4260  03atvow8404tatt2iixjds03atvownkz   36.0       35-39
# 4261        4261  02xomoejng6c9152kde02xomww412qpg   33.0       30-34
# 4262        4262  02vlm03c29g3fcys8tj06102vlm0983h   31.0       30-34
# 4264        4264  028mfisr3mqazkn5n6swe028mt55nqzq   37.0       35-39
#
#          GENERO COR/RACA/ETNIA  PCD  \
# 0     Masculino          Parda  Não
# 1     Masculino          Parda  Não
# 2     Masculino         Branca  Não
# 4      Feminino         Branca  Não
# 5      Feminino          Parda  Não
# ...         ...            ...  ...
# 4257  Masculino        Amarela  Não
# 4260  Masculino          Parda  Não
# 4261  Masculino         Branca  Não
# 4262  Masculino        Amarela  Não
# 4264  Masculino         Branca  Não
#
#                    EXPERIENCIA_PROFISSIONAL_PREJUDICADA  \
# 0     Não acredito que minha experiência profissiona...
# 1     Sim, acredito que a minha a experiência profis...
# 2                                                   NaN
# 4     Não acredito que minha experiência profissiona...
# 5     Não acredito que minha experiência profissiona...
# ...                                                 ...
# 4257  Não acredito que minha experiência profissiona...
# 4260  Não acredito que minha experiência profissiona...
# 4261                                                NaN
# 4262  Não acredito que minha experiência profissiona...
# 4264                                                NaN
#
#                              ASPECTOS_PREJUDICADOS  VIVE_NO_BRASIL  ...  \
# 0                                              NaN            True  ...
# 1     Aprovação em processos seletivos/entrevistas            True  ...
# 2                                              NaN            True  ...
# 4                                              NaN            True  ...
# 5                                              NaN            True  ...
# ...                                            ...             ...  ...
# 4257                                           NaN            True  ...
# 4260                                           NaN            True  ...
# 4261                                           NaN            True  ...
# 4262                                           NaN            True  ...
# 4264                                           NaN            True  ...
#
#                                SETOR NUMERO DE FUNCIONARIOS GESTOR?  \
# 0                      Setor Público         Acima de 3.000     0.0
# 1                        Outra Opção         Acima de 3.000     1.0
# 2                 Finanças ou Bancos         Acima de 3.000     0.0
# 4                      Setor Público           de 101 a 500     0.0
# 5                           Educação         Acima de 3.000     0.0
# ...                              ...                    ...     ...
# 4257              Finanças ou Bancos         Acima de 3.000     1.0
# 4260                             NaN                    NaN     NaN
# 4261                             NaN                    NaN     NaN
# 4262  Tecnologia/Fábrica de Software         de 501 a 1.000     1.0
# 4264  Tecnologia/Fábrica de Software            de 51 a 100     1.0
#
#             CARGO COMO GESTOR  \
# 0                         NaN
# 1      Supervisor/Coordenador
# 2                         NaN
# 4                         NaN
# 5                         NaN
# ...                       ...
# 4257             Gerente/Head
# 4260                      NaN
# 4261                      NaN
# 4262  Team Leader/Tech Leader
# 4264             Gerente/Head
#
#                                             CARGO ATUAL   NIVEL  \
# 0                   DBA/Administrador de Banco de Dados  Júnior
# 1                                                   NaN     NaN
# 2     Desenvolvedor/ Engenheiro de Software/ Analist...   Pleno
# 4     Desenvolvedor/ Engenheiro de Software/ Analist...   Pleno
# 5                                             Professor   Pleno
# ...                                                 ...     ...
# 4257                                                NaN     NaN
# 4260                                                NaN     NaN
# 4261                                                NaN     NaN
# 4262                                                NaN     NaN
# 4264                                                NaN     NaN
#
#                         FAIXA SALARIAL  \
# 0      de R$ 8.001/mês a R$ 12.000/mês
# 1       de R$ 4.001/mês a R$ 6.000/mês
# 2     de R$ 12.001/mês a R$ 16.000/mês
# 4       de R$ 6.001/mês a R$ 8.000/mês
# 5       de R$ 2.001/mês a R$ 3.000/mês
# ...                                ...
# 4257            Acima de R$ 40.001/mês
# 4260                               NaN
# 4261                               NaN
# 4262  de R$ 16.001/mês a R$ 20.000/mês
# 4264  de R$ 20.001/mês a R$ 25.000/mês
#
#      QUANTO TEMPO DE EXPERIÊNCIA NA ÁREA DE DADOS VOCÊ TEM?  \
# 0                                         de 1 a 2 anos
# 1                                         de 3 a 4 anos
# 2                                         de 3 a 4 anos
# 4                Não tenho experiência na área de dados
# 5                Não tenho experiência na área de dados
# ...                                                 ...
# 4257                                    Mais de 10 anos
# 4260                                                NaN
# 4261                                                NaN
# 4262                                      de 3 a 4 anos
# 4264                                      de 3 a 4 anos
#
#      QUANTO TEMPO DE EXPERIÊNCIA NA ÁREA DE TI/ENGENHARIA DE SOFTWARE VOCÊ TEVE ANTES DE COMEÇAR A TRABALHAR NA ÁREA DE DADOS?  \
# 0                                        de 7 a 10 anos
# 1                                        Menos de 1 ano
# 2                                       Mais de 10 anos
# 4                                       Mais de 10 anos
# 5     Não tive experiência na área de TI/Engenharia ...
# ...                                                 ...
# 4257  Não tive experiência na área de TI/Engenharia ...
# 4260                                                NaN
# 4261                                                NaN
# 4262                                      de 3 a 4 anos
# 4264                                    Mais de 10 anos
#
#       SALARIO
# 0     11194.0
# 1      4695.0
# 2     14202.0
# 4      7733.0
# 5      2336.0
# ...       ...
# 4257  62001.0
# 4260      NaN
# 4261      NaN
# 4262  18402.0
# 4264  24543.0
#
# [1956 rows x 28 columns]

# %%
dados[(dados["IDADE"]>30)& (dados ["GENERO"]=="Feminino")]
# Out:
#       Unnamed: 0                                ID  IDADE FAIXA IDADE  \
# 4              4  zzaf1m95yan929rb94wzzaf1mekhvhpg   46.0       45-49
# 5              5  zz0nlhbd8oxyiyxzz0nlh7g4xkiaza5v   32.0       30-34
# 7              7  zyc0twzno2sm5or5ovoxzyc0twz0300d   31.0       30-34
# 14            14  zwez49k0jhdvfkfst4zwef137uuf4ivy   35.0       35-39
# 23            23  zuqfcwtl9unfc5ezuqfcwm8coytsp5ap   46.0       45-49
# ...          ...                               ...    ...         ...
# 4214        4214  0gprow0ownrbfneftxf0gprow4kyrqdy   41.0       40-44
# 4221        4221  0fgi5bnb0u9b0fgc0jmqlbnvtu12b76d   34.0       30-34
# 4240        4240  0a5xgxb1ljmuqn0un8a10a5xg4eufs2l   37.0       35-39
# 4247        4247  07qzabp4ujpe4oz81udmb07qzabp4h0t   34.0       30-34
# 4251        4251  068hhicrqggu068huq0l2ab3g7liagy8   34.0       30-34
#
#         GENERO COR/RACA/ETNIA                   PCD  \
# 4     Feminino         Branca                   Não
# 5     Feminino          Parda                   Não
# 7     Feminino         Branca                   Não
# 14    Feminino          Parda                   Não
# 23    Feminino         Branca                   Não
# ...        ...            ...                   ...
# 4214  Feminino         Branca  Prefiro não informar
# 4221  Feminino          Outra                   Não
# 4240  Feminino         Branca                   Não
# 4247  Feminino         Branca                   Não
# 4251  Feminino          Preta                   Não
#
#                    EXPERIENCIA_PROFISSIONAL_PREJUDICADA  \
# 4     Não acredito que minha experiência profissiona...
# 5     Não acredito que minha experiência profissiona...
# 7     Não acredito que minha experiência profissiona...
# 14    Sim, acredito que a minha a experiência profis...
# 23    Não acredito que minha experiência profissiona...
# ...                                                 ...
# 4214  Sim, acredito que a minha a experiência profis...
# 4221  Não acredito que minha experiência profissiona...
# 4240  Sim, acredito que a minha a experiência profis...
# 4247  Não acredito que minha experiência profissiona...
# 4251  Não acredito que minha experiência profissiona...
#
#                                   ASPECTOS_PREJUDICADOS  VIVE_NO_BRASIL  ...  \
# 4                                                   NaN            True  ...
# 5                                                   NaN            True  ...
# 7                                                   NaN            True  ...
# 14    Atenção dada pelas pessoas diante das minhas o...            True  ...
# 23                                                  NaN            True  ...
# ...                                                 ...             ...  ...
# 4214  Oportunidades de progressão de carreira, Veloc...            True  ...
# 4221                                                NaN            True  ...
# 4240  Quantidade de oportunidades de emprego/vagas r...            True  ...
# 4247                                                NaN            True  ...
# 4251                                                NaN            True  ...
#
#                                SETOR NUMERO DE FUNCIONARIOS GESTOR?  \
# 4                      Setor Público           de 101 a 500     0.0
# 5                           Educação         Acima de 3.000     0.0
# 7     Tecnologia/Fábrica de Software              de 6 a 10     0.0
# 14                            Varejo         Acima de 3.000     0.0
# 23    Tecnologia/Fábrica de Software         de 501 a 1.000     0.0
# ...                              ...                    ...     ...
# 4214          Seguros ou Previdência         Acima de 3.000     1.0
# 4221             Área de Consultoria            de 51 a 100     0.0
# 4240              Finanças ou Bancos            de 51 a 100     0.0
# 4247                Setor de Energia             de 11 a 50     0.0
# 4251              Finanças ou Bancos       de 1.001 a 3.000     0.0
#
#            CARGO COMO GESTOR  \
# 4                        NaN
# 5                        NaN
# 7                        NaN
# 14                       NaN
# 23                       NaN
# ...                      ...
# 4214  Supervisor/Coordenador
# 4221                     NaN
# 4240                     NaN
# 4247                     NaN
# 4251                     NaN
#
#                                             CARGO ATUAL   NIVEL  \
# 4     Desenvolvedor/ Engenheiro de Software/ Analist...   Pleno
# 5                                             Professor   Pleno
# 7     Desenvolvedor/ Engenheiro de Software/ Analist...  Júnior
# 14                Analista de Negócios/Business Analyst   Pleno
# 23    Engenheiro de Dados/Arquiteto de Dados/Data En...  Sênior
# ...                                                 ...     ...
# 4214                                                NaN     NaN
# 4221                                        Outra Opção  Júnior
# 4240                          Analista de BI/BI Analyst  Júnior
# 4247                  Cientista de Dados/Data Scientist  Júnior
# 4251  Engenheiro de Dados/Arquiteto de Dados/Data En...   Pleno
#
#                         FAIXA SALARIAL  \
# 4       de R$ 6.001/mês a R$ 8.000/mês
# 5       de R$ 2.001/mês a R$ 3.000/mês
# 7       de R$ 2.001/mês a R$ 3.000/mês
# 14      de R$ 6.001/mês a R$ 8.000/mês
# 23    de R$ 12.001/mês a R$ 16.000/mês
# ...                                ...
# 4214   de R$ 8.001/mês a R$ 12.000/mês
# 4221    de R$ 4.001/mês a R$ 6.000/mês
# 4240    de R$ 1.001/mês a R$ 2.000/mês
# 4247    de R$ 4.001/mês a R$ 6.000/mês
# 4251    de R$ 4.001/mês a R$ 6.000/mês
#
#      QUANTO TEMPO DE EXPERIÊNCIA NA ÁREA DE DADOS VOCÊ TEM?  \
# 4                Não tenho experiência na área de dados
# 5                Não tenho experiência na área de dados
# 7                                        Menos de 1 ano
# 14                                        de 1 a 2 anos
# 23                                      Mais de 10 anos
# ...                                                 ...
# 4214                                      de 4 a 6 anos
# 4221                                     Menos de 1 ano
# 4240                                      de 1 a 2 anos
# 4247                                    Mais de 10 anos
# 4251                                     Menos de 1 ano
#
#      QUANTO TEMPO DE EXPERIÊNCIA NA ÁREA DE TI/ENGENHARIA DE SOFTWARE VOCÊ TEVE ANTES DE COMEÇAR A TRABALHAR NA ÁREA DE DADOS?  \
# 4                                       Mais de 10 anos
# 5     Não tive experiência na área de TI/Engenharia ...
# 7                                        Menos de 1 ano
# 14    Não tive experiência na área de TI/Engenharia ...
# 23                                        de 5 a 6 anos
# ...                                                 ...
# 4214  Não tive experiência na área de TI/Engenharia ...
# 4221                                     Menos de 1 ano
# 4240                                     Menos de 1 ano
# 4247  Não tive experiência na área de TI/Engenharia ...
# 4251                                     Menos de 1 ano
#
#       SALARIO
# 4      7733.0
# 5      2336.0
# 7      2704.0
# 14     7416.0
# 23    13418.0
# ...       ...
# 4214  11452.0
# 4221   5687.0
# 4240   1182.0
# 4247   5925.0
# 4251   5673.0
#
# [503 rows x 28 columns]

# %%
(dados[dados["COR/RACA/ETNIA"]=="Amarela"].shape)
# Out:
# (128, 28)

# %%
(dados[dados["IDADE"]<40]).shape
# Out:
# (3686, 28)

# %%
(dados[(dados["IDADE"] <40) & (dados["COR/RACA/ETNIA"]=="Amarela")]).shape
# Out:
# (101, 28)

# %%
dados=pd.read_csv("licitacoes.csv",sep=";" encoding="latin1")
# Out:
#   File "/tmp/ipykernel_2678/823812001.py", line 1
#     dados=pd.read_csv("licitacoes.csv",sep=";" encoding="latin1")
#                                            ^
# SyntaxError: invalid syntax. Perhaps you forgot a comma?

# %%
dados=pd.read_csv("/content/drive/MyDrive/Curso PrograMaria/licitacoes.csv",encoding="latin1",sep=";")

# %%
dados.columns
# Out:
# Index(['Número Licitação', 'Código UG', 'Nome UG', 'Código Modalidade Compra',
#        'Modalidade Compra', 'Número Processo', 'Objeto', 'Situação Licitação',
#        'Código Órgão Superior', 'Nome Órgão Superior', 'Código Órgão',
#        'Nome Órgão', 'UF', 'Município', 'Data Resultado Compra',
#        'Data Abertura', 'Valor Licitação'],
#       dtype='object')

# %%
dados[dados["Situação Licitação"]== "Encerrado"]
# Out:
#        Número Licitação  Código UG  \
# 3                 12018     925135
# 16                12018     130129
# 18                12018     135097
# 19                12018     152140
# 24                12018     153092
# ...                 ...        ...
# 15327         907662018     926130
# 15328         907732018     926130
# 15329         908252018     926130
# 15333         990922018     158139
# 15334         996252018     153035
#
#                                             Nome UG  Código Modalidade Compra  \
# 3                  BANCO CENTRAL DO BRASIL - RECIFE                         6
# 16       SUPERINT.REG.DE DESENV.DA LAV.CACAUEIRA/MT                         6
# 18                                     EMBRAPA CAFE                         7
# 19                    IFB - CAMPUS TAGUATINGA NORTE                         6
# 24                       BIBLIOTECA CENTRAL DA UFPE                         6
# ...                                             ...                       ...
# 15327  DIVISÃO DE CENTRO DE SERV COMPRATILHADOS BSB                         6
# 15328  DIVISÃO DE CENTRO DE SERV COMPRATILHADOS BSB                         6
# 15329  DIVISÃO DE CENTRO DE SERV COMPRATILHADOS BSB                         6
# 15333      INST.FED.DE EDUC.,CIENC.E TEC.FLUMINENSE                         6
# 15334     UNIVERSIDADE FEDERAL DO TRIANGULO MINEIRO                         6
#
#                   Modalidade Compra    Número Processo  \
# 3             Dispensa de Licitação             148097
# 16            Dispensa de Licitação   0000000000032018
# 18     Inexigibilidade de Licitação  21163.000694/2018
# 19            Dispensa de Licitação  23162004935201845
# 24            Dispensa de Licitação  23076025958201862
# ...                             ...                ...
# 15327         Dispensa de Licitação     PL.CSG.A.90766
# 15328         Dispensa de Licitação     PL.CSG.A.90773
# 15329         Dispensa de Licitação     PL.CSG.A.90825
# 15333         Dispensa de Licitação  23317009092201862
# 15334         Dispensa de Licitação  23085000625201811
#
#                                                   Objeto Situação Licitação  \
# 3      Objeto: TV LED de 65 polegadas, UHD 4k, com co...          Encerrado
# 16     Objeto: Atender despesas com telefonia fixa e ...          Encerrado
# 18     Objeto: Serviço de genotipagem de 384 amostras...          Encerrado
# 19     Objeto: Contratação de empesa especializada a ...          Encerrado
# 24     Objeto: Aquisição de Equipamento de Proteção I...          Encerrado
# ...                                                  ...                ...
# 15327  Objeto: Fornecimento de fogão, para entrega na...          Encerrado
# 15328  Objeto: Prestação de serviços para locação de ...          Encerrado
# 15329  Objeto: Coleta e descarte de resíduos industri...          Encerrado
# 15333  Objeto: Aquisição de material para revisão do ...          Encerrado
# 15334  Objeto: Pagamento da taxa referente ao primeir...          Encerrado
#
#        Código Órgão Superior                   Nome Órgão Superior  \
# 3                      20101                        Sem informação
# 16                     22000  Ministério da Agricultura e Pecuária
# 18                     22000  Ministério da Agricultura e Pecuária
# 19                     26000                Ministério da Educação
# 24                     26000                Ministério da Educação
# ...                      ...                                   ...
# 15327                  20101                        Sem informação
# 15328                  20101                        Sem informação
# 15329                  20101                        Sem informação
# 15333                  26000                Ministério da Educação
# 15334                  26000                Ministério da Educação
#
#        Código Órgão                                     Nome Órgão  UF  \
# 3             25201  BANCO CENTRAL DO BRASIL-ORC.FISCAL/SEG.SOCIAL  -3
# 16            22000    Ministério da Agricultura e Pecuária - Unid  MT
# 18            22202    Empresa Brasileira de Pesquisa Agropecuária  DF
# 19            26428                  Instituto Federal de Brasília  DF
# 24            26242             Universidade Federal de Pernambuco  PE
# ...             ...                                            ...  ..
# 15327         91081                 FURNAS-CENTRAIS ELETRICAS S.A.  -3
# 15328         91081                 FURNAS-CENTRAIS ELETRICAS S.A.  -3
# 15329         91081                 FURNAS-CENTRAIS ELETRICAS S.A.  -3
# 15333         26434                   Instituto Federal Fluminense  RJ
# 15334         26254      Universidade Federal do Triângulo Mineiro  MG
#
#                    Município Data Resultado Compra Data Abertura  \
# 3                   Inválido            04/12/2018    30/11/2018
# 16             ALTA FLORESTA            06/12/2018           NaN
# 18                  BRASILIA            04/12/2018           NaN
# 19                  BRASILIA            31/12/2018           NaN
# 24                    RECIFE            06/12/2018    29/11/2018
# ...                      ...                   ...           ...
# 15327               Inválido            10/12/2018    04/12/2018
# 15328               Inválido            20/12/2018    05/12/2018
# 15329               Inválido            21/12/2018    17/12/2018
# 15333  CAMPOS DOS GOYTACAZES            03/12/2018           NaN
# 15334                UBERABA            04/12/2018           NaN
#
#       Valor Licitação
# 3          11075,9900
# 16          1541,7000
# 18         90504,0000
# 19          2068,0000
# 24          5609,0000
# ...               ...
# 15327        817,2000
# 15328       8400,0000
# 15329       9040,0000
# 15333       1149,7500
# 15334        298,0000
#
# [9016 rows x 17 columns]

# %%
dados ["Situação Licitação"].value_counts()
# Out:
# Situação Licitação
# Encerrado                         9016
# Publicado                         3709
# Evento de Resultado de Julgame    1922
# Retificação                        127
# Evento de Alteração Publicad        93
# Evento de Suspensão Publicado       72
# Anulação                            67
# Revogação                           63
# Divulgado                           55
# Evento de Adiamento Publicado       46
# Evento de Retificação Public        45
# Evento de Revogação Publicad        40
# Evento de Alteração de Resul        37
# Evento de Anulação Publicado        18
# Evento de Retificação Divulg         7
# Inválido                             4
# Evento de Habilitação Public         4
# Evento de Alteração Divulgad         4
# Evento de Reabertura de Prazo        4
# Evento de Adiamento Divulgado        3
# Name: count, dtype: int64

# %%
dados.groupby("Situação Licitação")["Situação Licitação"].nunique()
# Out:
# Situação Licitação
# Anulação                          1
# Divulgado                         1
# Encerrado                         1
# Evento de Adiamento Divulgado     1
# Evento de Adiamento Publicado     1
# Evento de Alteração Divulgad      1
# Evento de Alteração Publicad      1
# Evento de Alteração de Resul      1
# Evento de Anulação Publicado      1
# Evento de Habilitação Public      1
# Evento de Reabertura de Prazo     1
# Evento de Resultado de Julgame    1
# Evento de Retificação Divulg      1
# Evento de Retificação Public      1
# Evento de Revogação Publicad      1
# Evento de Suspensão Publicado     1
# Inválido                          1
# Publicado                         1
# Retificação                       1
# Revogação                         1
# Name: Situação Licitação, dtype: int64

# %%
dados ["Situação Licitação"].nunique
# Out:
# <bound method IndexOpsMixin.nunique of 0        Evento de Resultado de Julgame
# 1        Evento de Resultado de Julgame
# 2        Evento de Resultado de Julgame
# 3                             Encerrado
# 4                             Publicado
#                       ...
# 15331    Evento de Resultado de Julgame
# 15332                         Publicado
# 15333                         Encerrado
# 15334                         Encerrado
# 15335                         Revogação
# Name: Situação Licitação, Length: 15336, dtype: object>

# %%
dados = pd.read_excel

# %%
dados = pd.read_excel("/content/drive/MyDrive/Curso PrograMaria/planilha_modulo3 (1).xlsx")

# %%
dados.groupby("GENERO")["ID"].nunique()
# Out:
# GENERO
# Feminino                1055
# Masculino               3194
# Prefiro não informar      12
# Name: ID, dtype: int64

# %%
dados.groupby("GENERO", dropna=False)["ID"].nunique()
# Out:
# GENERO
# Feminino                1055
# Masculino               3194
# Prefiro não informar      12
# NaN                        9
# Name: ID, dtype: int64

# %%
dados["GENERO"].value_counts(dropna=False)
# Out:
# GENERO
# Masculino               3194
# Feminino                1056
# Prefiro não informar      12
# NaN                        9
# Name: count, dtype: int64

# %%
dados.describe()
# Out:
#         Unnamed: 0        IDADE  MUDOU DE ESTADO?      GESTOR?        SALARIO
# count  4271.000000  4197.000000       4171.000000  3694.000000    3694.000000
# mean   2135.000000    31.169168          0.806281     0.193016   10969.266919
# std    1233.075829     6.902803          0.395258     0.394719   19419.753189
# min       0.000000    18.000000          0.000000     0.000000      35.000000
# 25%    1067.500000    26.000000          1.000000     0.000000    4269.500000
# 50%    2135.000000    30.000000          1.000000     0.000000    7625.500000
# 75%    3202.500000    35.000000          1.000000     0.000000   12778.500000
# max    4270.000000    54.000000          1.000000     1.000000  485191.000000

# %%
dados[dados["IDADE"]>30]["NIVEL"].value_counts()
# Out:
# NIVEL
# Sênior    525
# Pleno     408
# Júnior    274
# Name: count, dtype: int64

# %%
dados[(dados["IDADE"]>30) & (dados ["GENERO"]=="Feminino")] ["NIVEL"].value_counts()
# Out:
# NIVEL
# Pleno     117
# Sênior    114
# Júnior     96
# Name: count, dtype: int64

# %%
pd.pivot_table(dados,values=["ID"], index=["GENERO"], columns=["GESTOR?"], aggfunc="count")
# Out:
#                         ID
# GESTOR?                0.0  1.0
# GENERO
# Feminino               754  132
# Masculino             2212  578
# Prefiro não informar     9    2

# %% [markdown]
# # Estatística Básica

# %%
import numpy as np

# %%
lista_idades = [26, 30, 32, 22, 26, 35, 40, 20, 43, 31, 23]

# %%
np.sum (lista_idades)
# Out:
# np.int64(328)

# %%
len(lista_idades)
# Out:
# 11

# %%
np.sum (lista_idades)/len(lista_idades)
# Out:
# np.float64(29.818181818181817)

# %%
media = np.mean (lista_idades)
print ("Media aritmetica:", media)
# Out:
# Media aritmetica: 29.818181818181817

# %%
lista_idades.sort()
lista_idades
# Out:
# [20, 22, 23, 26, 26, 30, 31, 32, 35, 40, 43]

# %%
lista_idades = [26, 30, 32, 22, 26, 35, 40, 20, 43, 31, 23, 100]

# %%
lista_idades.sort()
lista_idades
# Out:
# [20, 22, 23, 26, 26, 30, 31, 32, 35, 40, 43, 100]

# %%
mediana=np.median(lista_idades)
mediana
# Out:
# np.float64(30.5)

# %% [markdown]
# ### Voltando para a tabela

# %%
dados ["IDADE"] .mean ()
# Out:
# np.float64(31.169168453657374)

# %%
dados["IDADE"].median()
# Out:
# 30.0

# %%
dados["IDADE"].mode()
# Out:
# 0    27.0
# Name: IDADE, dtype: float64

# %%
dados["IDADE"].std()
# Out:
# 6.902802832143141

# %%
dados["IDADE"].min()
# Out:
# 18.0

# %%
dados["IDADE"].max()
# Out:
# 54.0

# %%
dados[dados["GENERO"]=="Feminino"]["IDADE"].mean()
# Out:
# np.float64(31.318051575931232)

# %%
import pandas as pd

# %%
dados = pd.read_excel

# %%
dados = pd.read_excel("/content/drive/MyDrive/Curso PrograMaria/planilha_modulo3 (1).xlsx")

# %%
dados[dados["GENERO"]=="Masculino"]["IDADE"].mean()
# Out:
# np.float64(31.147876077930373)

# %%
dados[dados["GENERO"]=="Masculino"]["SALARIO"].mean()
# Out:
# np.float64(11724.552688172043)

# %% [markdown]
# # Valores Faltantes

# %%
dados.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4271 entries, 0 to 4270
# Data columns (total 28 columns):
#  #   Column                                                                                                                     Non-Null Count  Dtype
# ---  ------                                                                                                                     --------------  -----
#  0   Unnamed: 0                                                                                                                 4271 non-null   int64
#  1   ID                                                                                                                         4271 non-null   object
#  2   IDADE                                                                                                                      4197 non-null   float64
#  3   FAIXA IDADE                                                                                                                4271 non-null   object
#  4   GENERO                                                                                                                     4262 non-null   object
#  5   COR/RACA/ETNIA                                                                                                             4271 non-null   object
#  6   PCD                                                                                                                        4271 non-null   object
#  7   EXPERIENCIA_PROFISSIONAL_PREJUDICADA                                                                                       2190 non-null   object
#  8   ASPECTOS_PREJUDICADOS                                                                                                      837 non-null    object
#  9   VIVE_NO_BRASIL                                                                                                             4271 non-null   bool
#  10  ESTADO ONDE MORA                                                                                                           4156 non-null   object
#  11  UF ONDE MORA                                                                                                               4156 non-null   object
#  12  REGIAO ONDE MORA                                                                                                           4171 non-null   object
#  13  MUDOU DE ESTADO?                                                                                                           4171 non-null   float64
#  14  REGIAO DE ORIGEM                                                                                                           772 non-null    object
#  15  NIVEL DE ENSINO                                                                                                            4271 non-null   object
#  16  ÁREA DE FORMAÇÃO                                                                                                           4149 non-null   object
#  17  QUAL SUA SITUAÇÃO ATUAL DE TRABALHO?                                                                                       4271 non-null   object
#  18  SETOR                                                                                                                      3694 non-null   object
#  19  NUMERO DE FUNCIONARIOS                                                                                                     3694 non-null   object
#  20  GESTOR?                                                                                                                    3694 non-null   float64
#  21  CARGO COMO GESTOR                                                                                                          713 non-null    object
#  22  CARGO ATUAL                                                                                                                2981 non-null   object
#  23  NIVEL                                                                                                                      2981 non-null   object
#  24  FAIXA SALARIAL                                                                                                             3694 non-null   object
#  25  QUANTO TEMPO DE EXPERIÊNCIA NA ÁREA DE DADOS VOCÊ TEM?                                                                     3694 non-null   object
#  26  QUANTO TEMPO DE EXPERIÊNCIA NA ÁREA DE TI/ENGENHARIA DE SOFTWARE VOCÊ TEVE ANTES DE COMEÇAR A TRABALHAR NA ÁREA DE DADOS?  3694 non-null   object
#  27  SALARIO                                                                                                                    3694 non-null   float64
# dtypes: bool(1), float64(4), int64(1), object(22)
# memory usage: 905.2+ KB

# %% [markdown]
# ###Trabalhando coluna de gênero

# %%
dados.groupby("GENERO" , dropna=False)["ID"].nunique()
# Out:
# GENERO
# Feminino                1055
# Masculino               3194
# Prefiro não informar      12
# NaN                        9
# Name: ID, dtype: int64

# %%
dados["GENERO"]= dados["GENERO"].fillna ("Prefiro não informar")

# %%
dados.groupby("GENERO" , dropna=False)["ID"].nunique()
# Out:
# GENERO
# Feminino                1055
# Masculino               3194
# Prefiro não informar      21
# Name: ID, dtype: int64

# %% [markdown]
# ##Trabalhando Coluna de Idade

# %%
dados["IDADE"].isnull().value_counts()
# Out:
# IDADE
# False    4197
# True       74
# Name: count, dtype: int64

# %%
dados.columns
# Out:
# Index(['Unnamed: 0', 'ID', 'IDADE', 'FAIXA IDADE', 'GENERO', 'COR/RACA/ETNIA',
#        'PCD', 'EXPERIENCIA_PROFISSIONAL_PREJUDICADA', 'ASPECTOS_PREJUDICADOS',
#        'VIVE_NO_BRASIL', 'ESTADO ONDE MORA', 'UF ONDE MORA',
#        'REGIAO ONDE MORA', 'MUDOU DE ESTADO?', 'REGIAO DE ORIGEM',
#        'NIVEL DE ENSINO', 'ÁREA DE FORMAÇÃO',
#        'QUAL SUA SITUAÇÃO ATUAL DE TRABALHO?', 'SETOR',
#        'NUMERO DE FUNCIONARIOS', 'GESTOR?', 'CARGO COMO GESTOR', 'CARGO ATUAL',
#        'NIVEL', 'FAIXA SALARIAL',
#        'QUANTO TEMPO DE EXPERIÊNCIA NA ÁREA DE DADOS VOCÊ TEM?',
#        'QUANTO TEMPO DE EXPERIÊNCIA NA ÁREA DE TI/ENGENHARIA DE SOFTWARE VOCÊ TEVE ANTES DE COMEÇAR A TRABALHAR NA ÁREA DE DADOS?',
#        'SALARIO'],
#       dtype='object')

# %%
import pandas as pd
dados = pd.read_excel("/content/drive/MyDrive/Curso PrograMaria/planilha_modulo3 (1).xlsx")

# %%
dados[dados["IDADE"].isnull()]["FAIXA IDADE"].value_counts()
# Out:
# FAIXA IDADE
# 55+      68
# 17-21     6
# Name: count, dtype: int64

# %%
media_17_21 = dados[dados["FAIXA IDADE"]=="17-21"]["IDADE"].mean()
dados.loc[(dados["FAIXA IDADE"] =="17-21") & (dados["IDADE"].isnull()), "IDADE"]= media_17_21

# %%
media_17_21 = dados[dados["FAIXA IDADE"]=="17-21"]["IDADE"].mean()

# %%
dados.loc[(dados["FAIXA IDADE"] =="17-21") & (dados["IDADE"].isnull()), "IDADE"]= media_17_21

# %%
dados[dados["IDADE"].isnull()]["FAIXA IDADE"].value_counts()
# Out:
# FAIXA IDADE
# 55+    68
# Name: count, dtype: int64

# %%
dados[dados["FAIXA IDADE"]=="55+"]["IDADE"]
# Out:
# 9      NaN
# 66     NaN
# 96     NaN
# 121    NaN
# 156    NaN
#         ..
# 4001   NaN
# 4043   NaN
# 4048   NaN
# 4061   NaN
# 4215   NaN
# Name: IDADE, Length: 68, dtype: float64

# %%
dados[dados["FAIXA IDADE"]=="55+"]["NIVEL"]
# Out:
# 9        Pleno
# 66      Júnior
# 96       Pleno
# 121      Pleno
# 156     Júnior
#          ...
# 4001       NaN
# 4043       NaN
# 4048       NaN
# 4061       NaN
# 4215    Sênior
# Name: NIVEL, Length: 68, dtype: object

# %%
media_geral= dados["IDADE"].mean()
media_geral
# Out:
# np.float64(31.153517220250375)

# %%
dados.loc[(dados["FAIXA IDADE"]== "55+") & (dados["IDADE"].isnull()), "IDADE"] =media_geral

# %%
dados[dados["IDADE"].isnull()]["FAIXA IDADE"].value_counts()
# Out:
# Series([], Name: count, dtype: int64)

# %% [markdown]
# ###Tratando coluna salário

# %%
dados[dados["SALARIO"].isnull()]
# Out:
#       Unnamed: 0                                ID  IDADE FAIXA IDADE  \
# 12            12  zwr9hqcpg513kaopenzwr9hibaqmldto   31.0       30-34
# 28            28  ztgepgj82o9oix0nztgepq2trcay6gpv   24.0       22-24
# 34            34  zsa9i6njd3e594mw0tvlk4zsa9iw86i9   24.0       22-24
# 39            39  zr4b2vm7dapp3linwqwn7zr4b2vmagqx   32.0       30-34
# 63            63  zm7o5yquakof0j6zm7vh3o0letznhdvh   26.0       25-29
# ...          ...                               ...    ...         ...
# 4242        4242  09oxwp6lsdwhw09ox1uobuxa8cq2pzma   26.0       25-29
# 4252        4252  064pe9b1htw7mflhif064pe95dotv6yf   39.0       35-39
# 4258        4258  03zjgijmnwv9qrlzbr03zjgij1eae1hw   25.0       25-29
# 4260        4260  03atvow8404tatt2iixjds03atvownkz   36.0       35-39
# 4261        4261  02xomoejng6c9152kde02xomww412qpg   33.0       30-34
#
#          GENERO COR/RACA/ETNIA  PCD  \
# 12    Masculino         Branca  Não
# 28     Feminino          Parda  Não
# 34     Feminino         Branca  Não
# 39    Masculino          Parda  Não
# 63    Masculino         Branca  Não
# ...         ...            ...  ...
# 4242  Masculino         Branca  Não
# 4252  Masculino          Parda  Não
# 4258   Feminino         Branca  Não
# 4260  Masculino          Parda  Não
# 4261  Masculino         Branca  Não
#
#                    EXPERIENCIA_PROFISSIONAL_PREJUDICADA  \
# 12                                                  NaN
# 28    Sim, acredito que a minha a experiência profis...
# 34    Sim, acredito que a minha a experiência profis...
# 39    Não acredito que minha experiência profissiona...
# 63                                                  NaN
# ...                                                 ...
# 4242                                                NaN
# 4252  Não acredito que minha experiência profissiona...
# 4258  Sim, acredito que a minha a experiência profis...
# 4260  Não acredito que minha experiência profissiona...
# 4261                                                NaN
#
#                                   ASPECTOS_PREJUDICADOS  VIVE_NO_BRASIL  ...  \
# 12                                                  NaN            True  ...
# 28         Aprovação em processos seletivos/entrevistas            True  ...
# 34    Quantidade de oportunidades de emprego/vagas r...            True  ...
# 39                                                  NaN            True  ...
# 63                                                  NaN            True  ...
# ...                                                 ...             ...  ...
# 4242                                                NaN            True  ...
# 4252                                                NaN            True  ...
# 4258  Senioridade das vagas recebidas em relação à s...            True  ...
# 4260                                                NaN            True  ...
# 4261                                                NaN            True  ...
#
#      SETOR NUMERO DE FUNCIONARIOS GESTOR?  CARGO COMO GESTOR CARGO ATUAL  \
# 12     NaN                    NaN     NaN                NaN         NaN
# 28     NaN                    NaN     NaN                NaN         NaN
# 34     NaN                    NaN     NaN                NaN         NaN
# 39     NaN                    NaN     NaN                NaN         NaN
# 63     NaN                    NaN     NaN                NaN         NaN
# ...    ...                    ...     ...                ...         ...
# 4242   NaN                    NaN     NaN                NaN         NaN
# 4252   NaN                    NaN     NaN                NaN         NaN
# 4258   NaN                    NaN     NaN                NaN         NaN
# 4260   NaN                    NaN     NaN                NaN         NaN
# 4261   NaN                    NaN     NaN                NaN         NaN
#
#      NIVEL FAIXA SALARIAL  \
# 12     NaN            NaN
# 28     NaN            NaN
# 34     NaN            NaN
# 39     NaN            NaN
# 63     NaN            NaN
# ...    ...            ...
# 4242   NaN            NaN
# 4252   NaN            NaN
# 4258   NaN            NaN
# 4260   NaN            NaN
# 4261   NaN            NaN
#
#      QUANTO TEMPO DE EXPERIÊNCIA NA ÁREA DE DADOS VOCÊ TEM?  \
# 12                                                  NaN
# 28                                                  NaN
# 34                                                  NaN
# 39                                                  NaN
# 63                                                  NaN
# ...                                                 ...
# 4242                                                NaN
# 4252                                                NaN
# 4258                                                NaN
# 4260                                                NaN
# 4261                                                NaN
#
#      QUANTO TEMPO DE EXPERIÊNCIA NA ÁREA DE TI/ENGENHARIA DE SOFTWARE VOCÊ TEVE ANTES DE COMEÇAR A TRABALHAR NA ÁREA DE DADOS?  \
# 12                                                  NaN
# 28                                                  NaN
# 34                                                  NaN
# 39                                                  NaN
# 63                                                  NaN
# ...                                                 ...
# 4242                                                NaN
# 4252                                                NaN
# 4258                                                NaN
# 4260                                                NaN
# 4261                                                NaN
#
#      SALARIO
# 12       NaN
# 28       NaN
# 34       NaN
# 39       NaN
# 63       NaN
# ...      ...
# 4242     NaN
# 4252     NaN
# 4258     NaN
# 4260     NaN
# 4261     NaN
#
# [577 rows x 28 columns]

# %%
dados[dados["SALARIO"].isnull()]["FAIXA SALARIAL"].value_counts()
# Out:
# Series([], Name: count, dtype: int64)

# %%
mediana_salario = dados["SALARIO"].median()

# %%
dados.loc[dados["SALARIO"].isnull(), "SALARIO"] = mediana_salario

# %% [markdown]
# ###Valores Discrepantes

# %%
lista_idades = [26, 30, 32, 22, 26, 35, 40, 20, 43, 31, 23]

# %%
import numpy as np
np.mean(lista_idades)
# Out:
# np.float64(29.818181818181817)

# %%
lista_idades = [26, 30, 32, 22, 26, 35, 400, 20, 43, 31, 23]

# %%
media = np.mean(lista_idades)
media
# Out:
# np.float64(62.54545454545455)

# %%
desvio = np.std(lista_idades)
desvio
# Out:
# np.float64(106.89532997398872)

# %%
media + 3*desvio
# Out:
# np.float64(383.2314444674207)

# %%
media - 3*desvio
# Out:
# np.float64(-258.1405353765116)

# %%
import matplotlib.pyplot as plt

# %%
plt.boxplot(lista_idades)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7fc7eb271be0>,
#   <matplotlib.lines.Line2D at 0x7fc7eb271b80>],
#  'caps': [<matplotlib.lines.Line2D at 0x7fc7eb271280>,
#   <matplotlib.lines.Line2D at 0x7fc7f0127e60>],
#  'boxes': [<matplotlib.lines.Line2D at 0x7fc7ebbc7b90>],
#  'medians': [<matplotlib.lines.Line2D at 0x7fc7ebaf6cf0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7fc7ebaf6e40>],
#  'means': []}

# %%
plt.boxplot(dados["SALARIO"])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7fc7eb1c5df0>,
#   <matplotlib.lines.Line2D at 0x7fc7eb1c60f0>],
#  'caps': [<matplotlib.lines.Line2D at 0x7fc7eb1c62d0>,
#   <matplotlib.lines.Line2D at 0x7fc7eb1c65d0>],
#  'boxes': [<matplotlib.lines.Line2D at 0x7fc7eb1c5a60>],
#  'medians': [<matplotlib.lines.Line2D at 0x7fc7eb1c68d0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7fc7eb1c6c30>],
#  'means': []}

# %%
Q1 = dados["SALARIO"].quantile (0.25)
Q1
# Out:
# np.float64(4751.5)

# %%
plt.boxplot(dados["SALARIO"].values)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7fc7ddf75f10>,
#   <matplotlib.lines.Line2D at 0x7fc7ddf76210>],
#  'caps': [<matplotlib.lines.Line2D at 0x7fc7ddf76510>,
#   <matplotlib.lines.Line2D at 0x7fc7ddf76810>],
#  'boxes': [<matplotlib.lines.Line2D at 0x7fc7ddf300b0>],
#  'medians': [<matplotlib.lines.Line2D at 0x7fc7ddf76b10>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7fc7ddf76e10>],
#  'means': []}

# %%
Q3 = dados["SALARIO"].quantile (0.75)
Q3
# Out:
# np.float64(11794.5)

# %%
IQR = Q3 - Q1
IQR
# Out:
# np.float64(7043.0)

# %%
lim_superior = Q3 + (1.5*IQR)
lim_superior
# Out:
# np.float64(22359.0)

# %%
lim_inferior = Q1 - (1.5*IQR)
lim_inferior
# Out:
# np.float64(-5813.0)

# %%
dados["FAIXA SALARIAL"].value_counts()
# Out:
# FAIXA SALARIAL
# de R$ 8.001/mês a R$ 12.000/mês     752
# de R$ 4.001/mês a R$ 6.000/mês      584
# de R$ 6.001/mês a R$ 8.000/mês      527
# de R$ 12.001/mês a R$ 16.000/mês    437
# de R$ 3.001/mês a R$ 4.000/mês      303
# de R$ 2.001/mês a R$ 3.000/mês      285
# de R$ 16.001/mês a R$ 20.000/mês    229
# de R$ 1.001/mês a R$ 2.000/mês      216
# de R$ 20.001/mês a R$ 25.000/mês    134
# de R$ 25.001/mês a R$ 30.000/mês     77
# de R$ 30.001/mês a R$ 40.000/mês     70
# Acima de R$ 40.001/mês               45
# Menos de R$ 1.000/mês                35
# Name: count, dtype: int64

# %%
media_salario = dados["SALARIO"].mean()
media_salario
# Out:
# np.float64(10517.53348162023)

# %%
desvio_salario = dados["SALARIO"].std()
desvio_salario
# Out:
# 18096.210989118474

# %%
limite_superior = media_salario +(3*desvio_salario)
limite_superior
# Out:
# np.float64(64806.16644897565)

# %%
dados[dados["SALARIO"]>limite_superior]["FAIXA SALARIAL"].value_counts()
# Out:
# FAIXA SALARIAL
# Acima de R$ 40.001/mês              19
# de R$ 30.001/mês a R$ 40.000/mês     3
# Name: count, dtype: int64

# %%
media_30_40 = dados[(dados["FAIXA SALARIAL"]=="de R$ 30.001/mês a R$ 40.000/mês") & (dados["SALARIO"]<limite_superior)]["SALARIO"].mean()
media_30_40
# Out:
# np.float64(39002.194029850754)

# %%
dados.loc[(dados["FAIXA SALARIAL"]=="de R$ 30.001/mês a R$ 40.000/mês") & (dados["SALARIO"]>limite_superior) , "SALARIO"] = media_30_40

# %%
dados[dados["SALARIO"]>limite_superior]["FAIXA SALARIAL"].value_counts()
# Out:
# FAIXA SALARIAL
# Acima de R$ 40.001/mês    19
# Name: count, dtype: int64

# %%
media_40 = dados[(dados["FAIXA SALARIAL"]=="Acima de R$ 40.001/mês") & (dados["SALARIO"]<limite_superior)]["SALARIO"].mean()
media_40
# Out:
# np.float64(53127.846153846156)

# %%
dados.loc[(dados["FAIXA SALARIAL"]=="Acima de R$ 40.001/mês") & (dados["SALARIO"]>limite_superior) , "SALARIO"] =media_40

# %%
dados[dados["SALARIO"]<limite_superior]["FAIXA SALARIAL"].value_counts()
media_40
# Out:
# np.float64(53127.846153846156)

# %%
plt.boxplot(dados["SALARIO"])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7fc7eaf12a20>,
#   <matplotlib.lines.Line2D at 0x7fc7eaf12cc0>],
#  'caps': [<matplotlib.lines.Line2D at 0x7fc7eaf12fc0>,
#   <matplotlib.lines.Line2D at 0x7fc7eaf13260>],
#  'boxes': [<matplotlib.lines.Line2D at 0x7fc7eae51880>],
#  'medians': [<matplotlib.lines.Line2D at 0x7fc7eaf13560>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7fc7eaf13830>],
#  'means': []}

# %% [markdown]
# #Distribuição amostral e Intervalo de Confiança

# %%
salarios = dados ["SALARIO"]

# %%
salarios
# Out:
# 0       11194.0
# 1        4695.0
# 2       14202.0
# 3       15463.0
# 4        7733.0
#          ...
# 4266     4329.0
# 4267     3758.0
# 4268    19607.0
# 4269      989.0
# 4270     3079.0
# Name: SALARIO, Length: 4271, dtype: float64

# %%
import numpy as np
media_amostral = np.mean (salarios)
media_amostral
# Out:
# np.float64(9904.390109813306)

# %%
desvio_amostral = np.std (salarios)
desvio_amostral
# Out:
# 8306.104872579343

# %%
nivel_confianca = 0.95

# %%
tamanho_amostra = len (salarios)
tamanho_amostra
# Out:
# 4271

# %%
from scipy import stats

# %%
erro_padrao = stats.sem(salarios)
erro_padrao
# Out:
# np.float64(127.11109872023638)

# %%
intervalo_confianca = stats.t.interval(nivel_confianca, tamanho_amostra-1, loc = media_amostral, scale = erro_padrao)
intervalo_confianca
# Out:
# (np.float64(9655.186295869078), np.float64(10153.593923757535))

# %% [markdown]
# # Featuring Engeneering

# %%
def preencher_nivel(gestor, nivel):
  if gestor==1:
    return "Pessoa Gestora"
  else:
    return nivel

# %%
dados ["NOVO_NIVEL"] = dados.apply(lambda x: preencher_nivel(x ["GESTOR?"], x ["NIVEL"]), axis=1)

# %%
dados ["NOVO_NIVEL"].value_counts()
# Out:
# NOVO_NIVEL
# Pleno             1060
# Júnior            1023
# Sênior             898
# Pessoa Gestora     713
# Name: count, dtype: int64

# %%
dados ["NIVEL"]
# Out:
# 0       Júnior
# 1          NaN
# 2        Pleno
# 3       Sênior
# 4        Pleno
#          ...
# 4266     Pleno
# 4267     Pleno
# 4268       NaN
# 4269    Júnior
# 4270    Júnior
# Name: NIVEL, Length: 4271, dtype: object

# %%
dados = pd.get_dummies (dados, columns =["NIVEL"])

# %%
dados.columns
# Out:
# Index(['Unnamed: 0', 'ID', 'IDADE', 'FAIXA IDADE', 'GENERO', 'COR/RACA/ETNIA',
#        'PCD', 'EXPERIENCIA_PROFISSIONAL_PREJUDICADA', 'ASPECTOS_PREJUDICADOS',
#        'VIVE_NO_BRASIL', 'ESTADO ONDE MORA', 'UF ONDE MORA',
#        'REGIAO ONDE MORA', 'MUDOU DE ESTADO?', 'REGIAO DE ORIGEM',
#        'NIVEL DE ENSINO', 'ÁREA DE FORMAÇÃO',
#        'QUAL SUA SITUAÇÃO ATUAL DE TRABALHO?', 'SETOR',
#        'NUMERO DE FUNCIONARIOS', 'GESTOR?', 'CARGO COMO GESTOR', 'CARGO ATUAL',
#        'FAIXA SALARIAL',
#        'QUANTO TEMPO DE EXPERIÊNCIA NA ÁREA DE DADOS VOCÊ TEM?',
#        'QUANTO TEMPO DE EXPERIÊNCIA NA ÁREA DE TI/ENGENHARIA DE SOFTWARE VOCÊ TEVE ANTES DE COMEÇAR A TRABALHAR NA ÁREA DE DADOS?',
#        'SALARIO', 'NOVO_NIVEL', 'NIVEL_Júnior', 'NIVEL_Pleno', 'NIVEL_Sênior'],
#       dtype='object')

# %%
def determinar_geracao(idade):
  if 39<idade<=58:
    return "Geração X"
  elif 29<idade<=39:
    return "Millenial"
  elif 13<idade<=29:
    return "Geraçao Z"
  else:
    return "Outra geração"

# %%
dados["GERAÇAO"] = dados ["IDADE"].apply(determinar_geracao)

# %%
dados["GERAÇAO"].value_counts()
# Out:
# GERAÇAO
# Geraçao Z    1999
# Millenial    1761
# Geração X     511
# Name: count, dtype: int64

# %%
dados2 = pd.read_excel("/content/drive/MyDrive/Curso PrograMaria/Planilha_Aula_parte2.xlsx")

# %%
dados2.head()
# Out:
#                                  ID  \
# 0  zzqzz3l9ily8nuo2m7wyzzqzz3w48o96
# 1  zzls2oftfn9law393oezzls2ofhvfpzd
# 2  zzdwqzfqqp1ypc7ps6m0hzzdwqz292yi
# 3  zzbqh3uy7yk7k9qmkzzbqtb4s9faqspl
# 4  zzaf1m95yan929rb94wzzaf1mekhvhpg
#
#   Quanto tempo de experiência na área de dados você tem?  \
# 0                                      de 1 a 2 anos
# 1                                      de 3 a 4 anos
# 2                                      de 3 a 4 anos
# 3                                      de 4 a 6 anos
# 4             Não tenho experiência na área de dados
#
#   Quanto tempo de experiência na área de TI/Engenharia de Software você teve antes de começar a trabalhar na área de dados?  \
# 0                                     de 7 a 10 anos
# 1                                     Menos de 1 ano
# 2                                    Mais de 10 anos
# 3  Não tive experiência na área de TI/Engenharia ...
# 4                                    Mais de 10 anos
#
#   Você está satisfeito na sua empresa atual?  \
# 0                                       True
# 1                                      False
# 2                                      False
# 3                                       True
# 4                                      False
#
#   Qual o principal motivo da sua insatisfação com a empresa atual?  \
# 0                                                NaN
# 1  Falta de oportunidade de crescimento no empreg...
# 2  Falta de oportunidade de crescimento no empreg...
# 3                                                NaN
# 4  Falta de oportunidade de crescimento no empreg...
#
#   Você participou de entrevistas de emprego nos últimos 6 meses?  \
# 0  Não participei de entrevistas de emprego/proce...
# 1          Sim, fiz entrevistas mas não fui aprovado
# 2  Não participei de entrevistas de emprego/proce...
# 3               Sim, fui aprovado e mudei de emprego
# 4  Não participei de entrevistas de emprego/proce...
#
#   Você pretende mudar de emprego nos próximos 6 meses?  \
# 0  Não estou buscando e não pretendo mudar de emp...
# 1  Estou em busca de oportunidades dentro ou fora...
# 2  Não estou buscando, mas me considero aberto a ...
# 3  Não estou buscando, mas me considero aberto a ...
# 4  Não estou buscando, mas me considero aberto a ...
#
#   Quais os principais critérios que você leva em consideração no momento de decidir onde trabalhar?  \
# 0                                         Benefícios
# 1  Remuneração/Salário, Plano de carreira e oport...
# 2  Remuneração/Salário, Flexibilidade de trabalho...
# 3  Remuneração/Salário, Flexibilidade de trabalho...
# 4  Remuneração/Salário, Oportunidade de aprendiza...
#
#             Atualmente qual a sua forma de trabalho?  \
# 0                             Modelo 100% presencial
# 1                             Modelo 100% presencial
# 2  Modelo híbrido com dias fixos de trabalho pres...
# 3  Modelo híbrido flexível (o funcionário tem lib...
# 4                             Modelo 100% presencial
#
#            Qual a forma de trabalho ideal para você?  \
# 0  Modelo híbrido com dias fixos de trabalho pres...
# 1  Modelo híbrido flexível (o funcionário tem lib...
# 2  Modelo híbrido flexível (o funcionário tem lib...
# 3  Modelo híbrido flexível (o funcionário tem lib...
# 4                             Modelo 100% presencial
#
#   Caso sua empresa decida pelo modelo 100% presencial qual será sua atitude?  \
# 0   Vou aceitar e retornar ao modelo 100% presencial
# 1   Vou aceitar e retornar ao modelo 100% presencial
# 2  Vou procurar outra oportunidade no modelo híbr...
# 3  Vou procurar outra oportunidade no modelo híbr...
# 4   Vou aceitar e retornar ao modelo 100% presencial
#
#                Sua empresa passu por Layoff em 2022?  \
# 0  Não ocorreram layoffs/demissões em massa na em...
# 1  Não ocorreram layoffs/demissões em massa na em...
# 2  Não ocorreram layoffs/demissões em massa na em...
# 3  Não ocorreram layoffs/demissões em massa na em...
# 4  Não ocorreram layoffs/demissões em massa na em...
#
#                                              Atuacao  \
# 0                                Engenharia de Dados
# 1                                             Gestor
# 2   desenvolve modelos preditivos e algoritmos de...
# 3   desenvolve modelos preditivos e algoritmos de...
# 4                                      Outra atuação
#
#   Quais das linguagens listadas abaixo você utiliza no trabalho?
# 0                                                SQL
# 1                                                NaN
# 2                                                  1
# 3                                                  0
# 4                                                SQL

# %%
dados = dados.merge(dados2, on="ID" , how="left")

# %%
dados.columns
# Out:
# Index(['Unnamed: 0', 'ID', 'IDADE', 'FAIXA IDADE', 'GENERO', 'COR/RACA/ETNIA',
#        'PCD', 'EXPERIENCIA_PROFISSIONAL_PREJUDICADA', 'ASPECTOS_PREJUDICADOS',
#        'VIVE_NO_BRASIL', 'ESTADO ONDE MORA', 'UF ONDE MORA',
#        'REGIAO ONDE MORA', 'MUDOU DE ESTADO?', 'REGIAO DE ORIGEM',
#        'NIVEL DE ENSINO', 'ÁREA DE FORMAÇÃO',
#        'QUAL SUA SITUAÇÃO ATUAL DE TRABALHO?', 'SETOR',
#        'NUMERO DE FUNCIONARIOS', 'GESTOR?', 'CARGO COMO GESTOR', 'CARGO ATUAL',
#        'FAIXA SALARIAL',
#        'QUANTO TEMPO DE EXPERIÊNCIA NA ÁREA DE DADOS VOCÊ TEM?',
#        'QUANTO TEMPO DE EXPERIÊNCIA NA ÁREA DE TI/ENGENHARIA DE SOFTWARE VOCÊ TEVE ANTES DE COMEÇAR A TRABALHAR NA ÁREA DE DADOS?',
#        'SALARIO', 'NOVO_NIVEL', 'NIVEL_Júnior', 'NIVEL_Pleno', 'NIVEL_Sênior',
#        'GERAÇAO', 'Quanto tempo de experiência na área de dados você tem?',
#        'Quanto tempo de experiência na área de TI/Engenharia de Software você teve antes de começar a trabalhar na área de dados?',
#        'Você está satisfeito na sua empresa atual?',
#        'Qual o principal motivo da sua insatisfação com a empresa atual?',
#        'Você participou de entrevistas de emprego nos últimos 6 meses?',
#        'Você pretende mudar de emprego nos próximos 6 meses?',
#        'Quais os principais critérios que você leva em consideração no momento de decidir onde trabalhar?',
#        'Atualmente qual a sua forma de trabalho?',
#        'Qual a forma de trabalho ideal para você?',
#        'Caso sua empresa decida pelo modelo 100% presencial qual será sua atitude?',
#        'Sua empresa passu por Layoff em 2022?', 'Atuacao',
#        'Quais das linguagens listadas abaixo você utiliza no trabalho?'],
#       dtype='object')

# %%
dados['Você pretende mudar de emprego nos próximos 6 meses?'].value_counts()
# Out:
# Você pretende mudar de emprego nos próximos 6 meses?
# Não estou buscando, mas me considero aberto a outras oportunidades         1354
# Estou em busca de oportunidades dentro ou fora do Brasil                   1011
# Não estou buscando e não pretendo mudar de emprego nos próximos 6 meses     978
# Estou em busca de oportunidades, mas apenas fora do Brasil                  353
# Name: count, dtype: int64

# %%
dados ["EM BUSCA"] = dados ['Você pretende mudar de emprego nos próximos 6 meses?'].str.contains("em busca" , case=False)

# %%
dados ["EM BUSCA"].value_counts()
# Out:
# EM BUSCA
# False    2332
# True     1364
# Name: count, dtype: int64

# %%
dados ["ABERTO_OPORTUNIDADES"] = dados ['Você pretende mudar de emprego nos próximos 6 meses?'].str.contains("aberto" , case=False)

# %%
dados ["ABERTO_OPORTUNIDADES"].value_counts()
# Out:
# ABERTO_OPORTUNIDADES
# False    2342
# True     1354
# Name: count, dtype: int64

# %% [markdown]
# ######Faça Você Mesme | Featuring engineerring - nova coluna de Etnia - brancas, não branca e outras

# %%
dados["COR/RACA/ETNIA"].value_counts()
# Out:
# COR/RACA/ETNIA
# Branca                  2746
# Parda                   1054
# Preta                    291
# Amarela                  128
# Prefiro não informar      26
# Outra                     17
# Indígena                  11
# Name: count, dtype: int64

# %%
def deterninar_etnia(etnia):
  if etnia=="Branca":
    return "Branca"
  elif etnia=="Prefiro não informar":
    return "Outras"
  else:
    return "Não branco"

# %%
dados["ETNIA"] = dados ["COR/RACA/ETNIA"].apply(deterninar_etnia)

# %%
dados["ETNIA"].value_counts()
# Out:
# ETNIA
# Branca        2746
# Não branco    1501
# Outras          26
# Name: count, dtype: int64

# %% [markdown]
# #Correlação

# %%
correlaçao_continua = dados ["IDADE"].corr(dados["SALARIO"])
correlaçao_continua
# Out:
# np.float64(0.2902441968622099)

# %%
from scipy.stats import chi2_contingency

# %%
def cramer_coeficiente (coluna1 , coluna2):
  tabela_cruzada =np.array (pd.crosstab(coluna1, coluna2))
  chi2 = chi2_contingency(tabela_cruzada)[0]
  soma = np.sum (tabela_cruzada)
  mini = min(tabela_cruzada.shape)-1
  cramer = np.sqrt(chi2/(soma*mini))
  return cramer

# %%
cramer_coeficiente(dados ["COR/RACA/ETNIA"], dados ["NIVEL DE ENSINO"])
# Out:
# np.float64(0.04499106580480143)

# %%
tabela_cruzada =pd.crosstab(dados ["COR/RACA/ETNIA"], dados ["NIVEL DE ENSINO"])
tabela_cruzada
# Out:
# NIVEL DE ENSINO       Doutorado ou Phd  Estudante de Graduação  \
# COR/RACA/ETNIA
# Amarela                              7                      15
# Branca                             127                     365
# Indígena                             0                       2
# Outra                                0                       0
# Parda                               50                     178
# Prefiro não informar                 1                       2
# Preta                                6                      51
#
# NIVEL DE ENSINO       Graduação/Bacharelado  Mestrado  \
# COR/RACA/ETNIA
# Amarela                                  50        14
# Branca                                  999       355
# Indígena                                  4         2
# Outra                                     6         3
# Parda                                   333       113
# Prefiro não informar                     14         1
# Preta                                   104        33
#
# NIVEL DE ENSINO       Não tenho graduação formal  Prefiro não informar  \
# COR/RACA/ETNIA
# Amarela                                        2                     0
# Branca                                        65                     8
# Indígena                                       0                     0
# Outra                                          1                     0
# Parda                                         33                     3
# Prefiro não informar                           0                     1
# Preta                                          9                     0
#
# NIVEL DE ENSINO       Pós-graduação
# COR/RACA/ETNIA
# Amarela                          40
# Branca                          827
# Indígena                          3
# Outra                             7
# Parda                           344
# Prefiro não informar              7
# Preta                            88

# %%
np.array (tabela_cruzada)
# Out:
# array([[  7,  15,  50,  14,   2,   0,  40],
#        [127, 365, 999, 355,  65,   8, 827],
#        [  0,   2,   4,   2,   0,   0,   3],
#        [  0,   0,   6,   3,   1,   0,   7],
#        [ 50, 178, 333, 113,  33,   3, 344],
#        [  1,   2,  14,   1,   0,   1,   7],
#        [  6,  51, 104,  33,   9,   0,  88]])

# %% [markdown]
# #Faça Você Mesme | Correlação ✅

# %%
cruzada = pd.crosstab(dados["GENERO"], dados["NIVEL DE ENSINO"])
cruzada
# Out:
# NIVEL DE ENSINO       Doutorado ou Phd  Estudante de Graduação  \
# GENERO
# Feminino                            57                     104
# Masculino                          134                     506
# Prefiro não informar                 0                       1
#
# NIVEL DE ENSINO       Graduação/Bacharelado  Mestrado  \
# GENERO
# Feminino                                365       133
# Masculino                              1138       386
# Prefiro não informar                      4         1
#
# NIVEL DE ENSINO       Não tenho graduação formal  Prefiro não informar  \
# GENERO
# Feminino                                      24                     3
# Masculino                                     86                     8
# Prefiro não informar                           0                     1
#
# NIVEL DE ENSINO       Pós-graduação
# GENERO
# Feminino                        372
# Masculino                       936
# Prefiro não informar              5

# %%
np.array(cruzada)
# Out:
# array([[  57,  104,  365,  133,   24,    3,  372],
#        [ 134,  506, 1138,  386,   86,    8,  936],
#        [   0,    1,    4,    1,    0,    1,    5]])

# %%
from scipy.stats import chi2_contingency

# %%
def cramer_coeficiente (coluna1 , coluna2):
  cruzada = np.array (pd.crosstab(coluna1, coluna2))
  chi2 = chi2_contingency(cruzada)[0]
  soma = np.sum (cruzada)
  mini = min(cruzada.shape)-1
  cramer = np.sqrt(chi2/(soma*mini))
  return cramer

# %%
cramer_coeficiente(dados["GENERO"], dados["NIVEL DE ENSINO"])
# Out:
# np.float64(0.08522666596077665)

# %%
dados.to_csv("/content/drive/MyDrive/Curso PrograMaria/analise_dados.csv" , index=False)

# %% [markdown]
# #Conectando SQL com pandas

# %%
import sqlite3
import pandas as pd

# %%
conexao = sqlite3.connect ("/content/drive/MyDrive/Curso PrograMaria/status_brasil")

# %%
query = "SELECT * FROM Municipios_Brasileiros WHERE Cidade = 'Itaquaquecetuba';"

# %%
dados = pd.read_csv("/content/drive/MyDrive/Curso PrograMaria/analise_dados.csv")

# %%
dados.head()
# Out:
#    Unnamed: 0                                ID  IDADE FAIXA IDADE     GENERO  \
# 0           0  zzqzz3l9ily8nuo2m7wyzzqzz3w48o96   39.0       35-39  Masculino
# 1           1  zzls2oftfn9law393oezzls2ofhvfpzd   32.0       30-34  Masculino
# 2           2  zzdwqzfqqp1ypc7ps6m0hzzdwqz292yi   53.0       50-54  Masculino
# 3           3  zzbqh3uy7yk7k9qmkzzbqtb4s9faqspl   27.0       25-29  Masculino
# 4           4  zzaf1m95yan929rb94wzzaf1mekhvhpg   46.0       45-49   Feminino
#
#   COR/RACA/ETNIA  PCD               EXPERIENCIA_PROFISSIONAL_PREJUDICADA  \
# 0          Parda  Não  Não acredito que minha experiência profissiona...
# 1          Parda  Não  Sim, acredito que a minha a experiência profis...
# 2         Branca  Não                                                NaN
# 3         Branca  Não                                                NaN
# 4         Branca  Não  Não acredito que minha experiência profissiona...
#
#                           ASPECTOS_PREJUDICADOS  VIVE_NO_BRASIL  ...  \
# 0                                           NaN            True  ...
# 1  Aprovação em processos seletivos/entrevistas            True  ...
# 2                                           NaN            True  ...
# 3                                           NaN            True  ...
# 4                                           NaN            True  ...
#
#   Quais os principais critérios que você leva em consideração no momento de decidir onde trabalhar?  \
# 0                                         Benefícios
# 1  Remuneração/Salário, Plano de carreira e oport...
# 2  Remuneração/Salário, Flexibilidade de trabalho...
# 3  Remuneração/Salário, Flexibilidade de trabalho...
# 4  Remuneração/Salário, Oportunidade de aprendiza...
#
#             Atualmente qual a sua forma de trabalho?  \
# 0                             Modelo 100% presencial
# 1                             Modelo 100% presencial
# 2  Modelo híbrido com dias fixos de trabalho pres...
# 3  Modelo híbrido flexível (o funcionário tem lib...
# 4                             Modelo 100% presencial
#
#            Qual a forma de trabalho ideal para você?  \
# 0  Modelo híbrido com dias fixos de trabalho pres...
# 1  Modelo híbrido flexível (o funcionário tem lib...
# 2  Modelo híbrido flexível (o funcionário tem lib...
# 3  Modelo híbrido flexível (o funcionário tem lib...
# 4                             Modelo 100% presencial
#
#    Caso sua empresa decida pelo modelo 100% presencial qual será sua atitude?  \
# 0   Vou aceitar e retornar ao modelo 100% presencial
# 1   Vou aceitar e retornar ao modelo 100% presencial
# 2  Vou procurar outra oportunidade no modelo híbr...
# 3  Vou procurar outra oportunidade no modelo híbr...
# 4   Vou aceitar e retornar ao modelo 100% presencial
#
#                Sua empresa passu por Layoff em 2022?  \
# 0  Não ocorreram layoffs/demissões em massa na em...
# 1  Não ocorreram layoffs/demissões em massa na em...
# 2  Não ocorreram layoffs/demissões em massa na em...
# 3  Não ocorreram layoffs/demissões em massa na em...
# 4  Não ocorreram layoffs/demissões em massa na em...
#
#                                              Atuacao  \
# 0                                Engenharia de Dados
# 1                                             Gestor
# 2   desenvolve modelos preditivos e algoritmos de...
# 3   desenvolve modelos preditivos e algoritmos de...
# 4                                      Outra atuação
#
#   Quais das linguagens listadas abaixo você utiliza no trabalho? EM BUSCA  \
# 0                                                SQL                False
# 1                                                NaN                 True
# 2                                                  1                False
# 3                                                  0                False
# 4                                                SQL                False
#
#   ABERTO_OPORTUNIDADES       ETNIA
# 0                False  Não branco
# 1                False  Não branco
# 2                 True      Branca
# 3                 True      Branca
# 4                 True      Branca
#
# [5 rows x 48 columns]

# %%
dados.columns
# Out:
# Index(['Unnamed: 0', 'ID', 'IDADE', 'FAIXA IDADE', 'GENERO', 'COR/RACA/ETNIA',
#        'PCD', 'EXPERIENCIA_PROFISSIONAL_PREJUDICADA', 'ASPECTOS_PREJUDICADOS',
#        'VIVE_NO_BRASIL', 'ESTADO ONDE MORA', 'UF ONDE MORA',
#        'REGIAO ONDE MORA', 'MUDOU DE ESTADO?', 'REGIAO DE ORIGEM',
#        'NIVEL DE ENSINO', 'ÁREA DE FORMAÇÃO',
#        'QUAL SUA SITUAÇÃO ATUAL DE TRABALHO?', 'SETOR',
#        'NUMERO DE FUNCIONARIOS', 'GESTOR?', 'CARGO COMO GESTOR', 'CARGO ATUAL',
#        'FAIXA SALARIAL',
#        'QUANTO TEMPO DE EXPERIÊNCIA NA ÁREA DE DADOS VOCÊ TEM?',
#        'QUANTO TEMPO DE EXPERIÊNCIA NA ÁREA DE TI/ENGENHARIA DE SOFTWARE VOCÊ TEVE ANTES DE COMEÇAR A TRABALHAR NA ÁREA DE DADOS?',
#        'SALARIO', 'NOVO_NIVEL', 'NIVEL_Júnior', 'NIVEL_Pleno', 'NIVEL_Sênior',
#        'GERAÇAO', 'Quanto tempo de experiência na área de dados você tem?',
#        'Quanto tempo de experiência na área de TI/Engenharia de Software você teve antes de começar a trabalhar na área de dados?',
#        'Você está satisfeito na sua empresa atual?',
#        'Qual o principal motivo da sua insatisfação com a empresa atual?',
#        'Você participou de entrevistas de emprego nos últimos 6 meses?',
#        'Você pretende mudar de emprego nos próximos 6 meses?',
#        'Quais os principais critérios que você leva em consideração no momento de decidir onde trabalhar?',
#        'Atualmente qual a sua forma de trabalho?',
#        'Qual a forma de trabalho ideal para você?',
#        'Caso sua empresa decida pelo modelo 100% presencial qual será sua atitude?',
#        'Sua empresa passu por Layoff em 2022?', 'Atuacao',
#        'Quais das linguagens listadas abaixo você utiliza no trabalho?',
#        'EM BUSCA', 'ABERTO_OPORTUNIDADES', 'ETNIA'],
#       dtype='object')

# %%
lista_estado = list (dados ['UF ONDE MORA'].unique())

# %%
lista_estado
# Out:
# ['DF',
#  'PA',
#  'MG',
#  'CE',
#  'SP',
#  'RS',
#  'BA',
#  'RJ',
#  'MS',
#  'PB',
#  'MT',
#  'PR',
#  'ES',
#  nan,
#  'SC',
#  'PE',
#  'RN',
#  'SE',
#  'AL',
#  'GO',
#  'MA',
#  'AM',
#  'PI']

# %%
query = """SELECT Municipios_Brasileiros.Estado, AVG(Municipio_Status.renda) as media_renda FROM Municipios_Brasileiros INNER JOIN Municipio_Status
ON Municipios_Brasileiros.municipio_ID = Municipio_Status.municipio_ID WHERE Municipios_Brasileiros.Estado IN ({})
GROUP BY Municipios_Brasileiros.Estado; """ .format("," .join(["?" for _ in lista_estado]))

# %%
pd.read_sql(query, con = conexao, params=lista_estado)
# Out:
#    Estado  media_renda
# 0      AL     0.548363
# 1      AM     0.545113
# 2      BA     0.574805
# 3      CE     0.559293
# 4      DF     0.863000
# 5      ES     0.680628
# 6      GO     0.683980
# 7      MA     0.531664
# 8      MG     0.652008
# 9      MS     0.687846
# 10     MT     0.682149
# 11     PA     0.572357
# 12     PB     0.564423
# 13     PE     0.574378
# 14     PI     0.546813
# 15     PR     0.691915
# 16     RJ     0.704796
# 17     RN     0.580183
# 18     RS     0.722115
# 19     SC     0.728038
# 20     SE     0.577147
# 21     SP     0.716571

# %%
print (query)
# Out:
# SELECT Municipios_Brasileiros.Estado, AVG(Municipio_Status.renda) as media_renda FROM Municipios_Brasileiros INNER JOIN Municipio_Status
# ON Municipios_Brasileiros.municipio_ID = Municipio_Status.municipio_ID WHERE Municipios_Brasileiros.Estado IN (?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?)
# GROUP BY Municipios_Brasileiros.Estado;

# %%
estados_renda = pd.read_sql(query, con = conexao, params=lista_estado)

# %%
pd.read_sql("""SELECT DISTINCT Estado from Municipios_Brasileiros""", con = conexao)
# Out:
#    Estado
# 0      AC
# 1      AL
# 2      AM
# 3      AP
# 4      BA
# 5      CE
# 6      DF
# 7      ES
# 8      GO
# 9      MA
# 10     MG
# 11     MS
# 12     MT
# 13     PA
# 14     PB
# 15     PE
# 16     PI
# 17     PR
# 18     RJ
# 19     RN
# 20     RO
# 21     RR
# 22     RS
# 23     SC
# 24     SE
# 25     SP
# 26     TO

# %%
estados_renda.head()
# Out:
#   Estado  media_renda
# 0     AL     0.548363
# 1     AM     0.545113
# 2     BA     0.574805
# 3     CE     0.559293
# 4     DF     0.863000

# %%
dados.columns
# Out:
# Index(['Unnamed: 0', 'ID', 'IDADE', 'FAIXA IDADE', 'GENERO', 'COR/RACA/ETNIA',
#        'PCD', 'EXPERIENCIA_PROFISSIONAL_PREJUDICADA', 'ASPECTOS_PREJUDICADOS',
#        'VIVE_NO_BRASIL', 'ESTADO ONDE MORA', 'UF ONDE MORA',
#        'REGIAO ONDE MORA', 'MUDOU DE ESTADO?', 'REGIAO DE ORIGEM',
#        'NIVEL DE ENSINO', 'ÁREA DE FORMAÇÃO',
#        'QUAL SUA SITUAÇÃO ATUAL DE TRABALHO?', 'SETOR',
#        'NUMERO DE FUNCIONARIOS', 'GESTOR?', 'CARGO COMO GESTOR', 'CARGO ATUAL',
#        'FAIXA SALARIAL',
#        'QUANTO TEMPO DE EXPERIÊNCIA NA ÁREA DE DADOS VOCÊ TEM?',
#        'QUANTO TEMPO DE EXPERIÊNCIA NA ÁREA DE TI/ENGENHARIA DE SOFTWARE VOCÊ TEVE ANTES DE COMEÇAR A TRABALHAR NA ÁREA DE DADOS?',
#        'SALARIO', 'NOVO_NIVEL', 'NIVEL_Júnior', 'NIVEL_Pleno', 'NIVEL_Sênior',
#        'GERAÇAO', 'Quanto tempo de experiência na área de dados você tem?',
#        'Quanto tempo de experiência na área de TI/Engenharia de Software você teve antes de começar a trabalhar na área de dados?',
#        'Você está satisfeito na sua empresa atual?',
#        'Qual o principal motivo da sua insatisfação com a empresa atual?',
#        'Você participou de entrevistas de emprego nos últimos 6 meses?',
#        'Você pretende mudar de emprego nos próximos 6 meses?',
#        'Quais os principais critérios que você leva em consideração no momento de decidir onde trabalhar?',
#        'Atualmente qual a sua forma de trabalho?',
#        'Qual a forma de trabalho ideal para você?',
#        'Caso sua empresa decida pelo modelo 100% presencial qual será sua atitude?',
#        'Sua empresa passu por Layoff em 2022?', 'Atuacao',
#        'Quais das linguagens listadas abaixo você utiliza no trabalho?',
#        'EM BUSCA', 'ABERTO_OPORTUNIDADES', 'ETNIA'],
#       dtype='object')

# %%
dados.rename(columns={"UF ONDE MORA": "Estado"}, inplace=True)

# %%
dados.columns
# Out:
# Index(['Unnamed: 0', 'ID', 'IDADE', 'FAIXA IDADE', 'GENERO', 'COR/RACA/ETNIA',
#        'PCD', 'EXPERIENCIA_PROFISSIONAL_PREJUDICADA', 'ASPECTOS_PREJUDICADOS',
#        'VIVE_NO_BRASIL', 'ESTADO ONDE MORA', 'Estado', 'REGIAO ONDE MORA',
#        'MUDOU DE ESTADO?', 'REGIAO DE ORIGEM', 'NIVEL DE ENSINO',
#        'ÁREA DE FORMAÇÃO', 'QUAL SUA SITUAÇÃO ATUAL DE TRABALHO?', 'SETOR',
#        'NUMERO DE FUNCIONARIOS', 'GESTOR?', 'CARGO COMO GESTOR', 'CARGO ATUAL',
#        'FAIXA SALARIAL',
#        'QUANTO TEMPO DE EXPERIÊNCIA NA ÁREA DE DADOS VOCÊ TEM?',
#        'QUANTO TEMPO DE EXPERIÊNCIA NA ÁREA DE TI/ENGENHARIA DE SOFTWARE VOCÊ TEVE ANTES DE COMEÇAR A TRABALHAR NA ÁREA DE DADOS?',
#        'SALARIO', 'NOVO_NIVEL', 'NIVEL_Júnior', 'NIVEL_Pleno', 'NIVEL_Sênior',
#        'GERAÇAO', 'Quanto tempo de experiência na área de dados você tem?',
#        'Quanto tempo de experiência na área de TI/Engenharia de Software você teve antes de começar a trabalhar na área de dados?',
#        'Você está satisfeito na sua empresa atual?',
#        'Qual o principal motivo da sua insatisfação com a empresa atual?',
#        'Você participou de entrevistas de emprego nos últimos 6 meses?',
#        'Você pretende mudar de emprego nos próximos 6 meses?',
#        'Quais os principais critérios que você leva em consideração no momento de decidir onde trabalhar?',
#        'Atualmente qual a sua forma de trabalho?',
#        'Qual a forma de trabalho ideal para você?',
#        'Caso sua empresa decida pelo modelo 100% presencial qual será sua atitude?',
#        'Sua empresa passu por Layoff em 2022?', 'Atuacao',
#        'Quais das linguagens listadas abaixo você utiliza no trabalho?',
#        'EM BUSCA', 'ABERTO_OPORTUNIDADES', 'ETNIA'],
#       dtype='object')

# %%
dados = dados.merge(estados_renda, on="Estado", how="left")

# %%
dados.head(10)
# Out:
#    Unnamed: 0                                ID      IDADE FAIXA IDADE  \
# 0           0  zzqzz3l9ily8nuo2m7wyzzqzz3w48o96  39.000000       35-39
# 1           1  zzls2oftfn9law393oezzls2ofhvfpzd  32.000000       30-34
# 2           2  zzdwqzfqqp1ypc7ps6m0hzzdwqz292yi  53.000000       50-54
# 3           3  zzbqh3uy7yk7k9qmkzzbqtb4s9faqspl  27.000000       25-29
# 4           4  zzaf1m95yan929rb94wzzaf1mekhvhpg  46.000000       45-49
# 5           5  zz0nlhbd8oxyiyxzz0nlh7g4xkiaza5v  32.000000       30-34
# 6           6  zytlxsdgalh22cgrijvzytlxa49i8yzx  21.000000       17-21
# 7           7  zyc0twzno2sm5or5ovoxzyc0twz0300d  31.000000       30-34
# 8           8  zy4o5dk6iuxpdwgzy4o58xvd6ykwohrj  33.000000       30-34
# 9           9  zxc3d314cn1c2ovmzxc34ha7nkw1na3j  31.153517         55+
#
#       GENERO COR/RACA/ETNIA  PCD  \
# 0  Masculino          Parda  Não
# 1  Masculino          Parda  Não
# 2  Masculino         Branca  Não
# 3  Masculino         Branca  Não
# 4   Feminino         Branca  Não
# 5   Feminino          Parda  Não
# 6  Masculino          Parda  Não
# 7   Feminino         Branca  Não
# 8  Masculino         Branca  Não
# 9   Feminino          Parda  Não
#
#                 EXPERIENCIA_PROFISSIONAL_PREJUDICADA  \
# 0  Não acredito que minha experiência profissiona...
# 1  Sim, acredito que a minha a experiência profis...
# 2                                                NaN
# 3                                                NaN
# 4  Não acredito que minha experiência profissiona...
# 5  Não acredito que minha experiência profissiona...
# 6  Não acredito que minha experiência profissiona...
# 7  Não acredito que minha experiência profissiona...
# 8                                                NaN
# 9  Não acredito que minha experiência profissiona...
#
#                           ASPECTOS_PREJUDICADOS  VIVE_NO_BRASIL  ...  \
# 0                                           NaN            True  ...
# 1  Aprovação em processos seletivos/entrevistas            True  ...
# 2                                           NaN            True  ...
# 3                                           NaN            True  ...
# 4                                           NaN            True  ...
# 5                                           NaN            True  ...
# 6                                           NaN            True  ...
# 7                                           NaN            True  ...
# 8                                           NaN            True  ...
# 9                                           NaN            True  ...
#
#             Atualmente qual a sua forma de trabalho?  \
# 0                             Modelo 100% presencial
# 1                             Modelo 100% presencial
# 2  Modelo híbrido com dias fixos de trabalho pres...
# 3  Modelo híbrido flexível (o funcionário tem lib...
# 4                             Modelo 100% presencial
# 5                             Modelo 100% presencial
# 6  Modelo híbrido com dias fixos de trabalho pres...
# 7                             Modelo 100% presencial
# 8                                 Modelo 100% remoto
# 9  Modelo híbrido com dias fixos de trabalho pres...
#
#            Qual a forma de trabalho ideal para você?  \
# 0  Modelo híbrido com dias fixos de trabalho pres...
# 1  Modelo híbrido flexível (o funcionário tem lib...
# 2  Modelo híbrido flexível (o funcionário tem lib...
# 3  Modelo híbrido flexível (o funcionário tem lib...
# 4                             Modelo 100% presencial
# 5  Modelo híbrido flexível (o funcionário tem lib...
# 6  Modelo híbrido flexível (o funcionário tem lib...
# 7                                 Modelo 100% remoto
# 8  Modelo híbrido flexível (o funcionário tem lib...
# 9  Modelo híbrido com dias fixos de trabalho pres...
#
#   Caso sua empresa decida pelo modelo 100% presencial qual será sua atitude?  \
# 0   Vou aceitar e retornar ao modelo 100% presencial
# 1   Vou aceitar e retornar ao modelo 100% presencial
# 2  Vou procurar outra oportunidade no modelo híbr...
# 3  Vou procurar outra oportunidade no modelo híbr...
# 4   Vou aceitar e retornar ao modelo 100% presencial
# 5   Vou aceitar e retornar ao modelo 100% presencial
# 6   Vou aceitar e retornar ao modelo 100% presencial
# 7  Vou procurar outra oportunidade no modelo 100%...
# 8  Vou procurar outra oportunidade no modelo híbr...
# 9  Vou procurar outra oportunidade no modelo híbr...
#
#                Sua empresa passu por Layoff em 2022?  \
# 0  Não ocorreram layoffs/demissões em massa na em...
# 1  Não ocorreram layoffs/demissões em massa na em...
# 2  Não ocorreram layoffs/demissões em massa na em...
# 3  Não ocorreram layoffs/demissões em massa na em...
# 4  Não ocorreram layoffs/demissões em massa na em...
# 5  Não ocorreram layoffs/demissões em massa na em...
# 6  Não ocorreram layoffs/demissões em massa na em...
# 7  Não ocorreram layoffs/demissões em massa na em...
# 8  Sim, ocorreram layoffs/demissões em massa na e...
# 9  Sim, ocorreram layoffs/demissões em massa na e...
#
#                                              Atuacao  \
# 0                                Engenharia de Dados
# 1                                             Gestor
# 2   desenvolve modelos preditivos e algoritmos de...
# 3   desenvolve modelos preditivos e algoritmos de...
# 4                                      Outra atuação
# 5                                      Outra atuação
# 6                                   Análise de Dados
# 7                                      Outra atuação
# 8                                   Análise de Dados
# 9                                      Outra atuação
#
#   Quais das linguagens listadas abaixo você utiliza no trabalho? EM BUSCA  \
# 0                                                SQL                False
# 1                                                NaN                 True
# 2                                                  1                False
# 3                                                  0                False
# 4                                                SQL                False
# 5        Não utilizo nenhuma das linguagens listadas                 True
# 6                             SQL, Python, SAS/Stata                False
# 7                                    SQL, JavaScript                 True
# 8                              SQL, Visual Basic/VBA                False
# 9                                                SQL                False
#
#   ABERTO_OPORTUNIDADES       ETNIA media_renda
# 0                False  Não branco    0.863000
# 1                False  Não branco    0.572357
# 2                 True      Branca    0.863000
# 3                 True      Branca    0.652008
# 4                 True      Branca    0.572357
# 5                False  Não branco    0.559293
# 6                False  Não branco    0.716571
# 7                False      Branca    0.722115
# 8                False      Branca    0.716571
# 9                 True  Não branco    0.574805
#
# [10 rows x 49 columns]

# %%
correlacao_renda_salario = dados ["SALARIO"]. corr (dados ["media_renda"])
correlacao_renda_salario
# Out:
# np.float64(0.12083384881429463)

# %%
query_aula_faca_voce = """SELECT Municipios_Brasileiros.Estado, AVG(Municipio_Status.educacao) FROM Municipios_Brasileiros INNER JOIN Municipio_Status ON Municipios_Brasileiros.municipio_ID = Municipio_Status.municipio_ID WHERE Municipios_Brasileiros.Estado IN ({})
 GROUP BY Municipios_Brasileiros.Estado; """.format(",".join(["?" for _ in lista_estado]))

# %%
estados_educacao = pd.read_sql(query_aula_faca_voce, con = conexao, params = lista_estado)

# %%
dados = dados.merge(estados_educacao, on = "Estado", how = "left")

# %%
correlacao_educacao_salario = dados ["SALARIO"]. corr(dados [ "AVG(Municipio_Status.educacao)"])
correlacao_educacao_salario
# Out:
# np.float64(0.15558020288268756)

# %% [markdown]
# #Visualização de Dados

# %%
import pandas as pd

# %%
dados5 = pd.read_csv ("/content/drive/MyDrive/Curso PrograMaria/Copia de analise_dados_2 - analise_dados.csv")

# %%
dados5.head()
# Out:
#                                  ID IDADE FAIXA IDADE     GENERO  \
# 0  zzqzz3l9ily8nuo2m7wyzzqzz3w48o96  39.0       35-39  Masculino
# 1  zzls2oftfn9law393oezzls2ofhvfpzd  32.0       30-34  Masculino
# 2  zzdwqzfqqp1ypc7ps6m0hzzdwqz292yi  53.0       50-54  Masculino
# 3  zzbqh3uy7yk7k9qmkzzbqtb4s9faqspl  27.0       25-29  Masculino
# 4  zzaf1m95yan929rb94wzzaf1mekhvhpg  46.0       45-49   Feminino
#
#   COR/RACA/ETNIA  PCD               EXPERIENCIA_PROFISSIONAL_PREJUDICADA  \
# 0          Parda  Não  Não acredito que minha experiência profissiona...
# 1          Parda  Não  Sim, acredito que a minha a experiência profis...
# 2         Branca  Não                                                NaN
# 3         Branca  Não                                                NaN
# 4         Branca  Não  Não acredito que minha experiência profissiona...
#
#                           ASPECTOS_PREJUDICADOS  VIVE_NO_BRASIL  \
# 0                                           NaN            True
# 1  Aprovação em processos seletivos/entrevistas            True
# 2                                           NaN            True
# 3                                           NaN            True
# 4                                           NaN            True
#
#         ESTADO ONDE MORA  ...  \
# 0  Distrito Federal (DF)  ...
# 1              Pará (PA)  ...
# 2  Distrito Federal (DF)  ...
# 3      Minas Gerais (MG)  ...
# 4              Pará (PA)  ...
#
#   Você pretende mudar de emprego nos próximos 6 meses?  \
# 0  Não estou buscando e não pretendo mudar de emp...
# 1  Estou em busca de oportunidades dentro ou fora...
# 2  Não estou buscando, mas me considero aberto a ...
# 3  Não estou buscando, mas me considero aberto a ...
# 4  Não estou buscando, mas me considero aberto a ...
#
#   Quais os principais critérios que você leva em consideração no momento de decidir onde trabalhar?  \
# 0                                         Benefícios
# 1  Remuneração/Salário, Plano de carreira e oport...
# 2  Remuneração/Salário, Flexibilidade de trabalho...
# 3  Remuneração/Salário, Flexibilidade de trabalho...
# 4  Remuneração/Salário, Oportunidade de aprendiza...
#
#             Atualmente qual a sua forma de trabalho?  \
# 0                             Modelo 100% presencial
# 1                             Modelo 100% presencial
# 2  Modelo híbrido com dias fixos de trabalho pres...
# 3  Modelo híbrido flexível (o funcionário tem lib...
# 4                             Modelo 100% presencial
#
#            Qual a forma de trabalho ideal para você?  \
# 0  Modelo híbrido com dias fixos de trabalho pres...
# 1  Modelo híbrido flexível (o funcionário tem lib...
# 2  Modelo híbrido flexível (o funcionário tem lib...
# 3  Modelo híbrido flexível (o funcionário tem lib...
# 4                             Modelo 100% presencial
#
#   Caso sua empresa decida pelo modelo 100% presencial qual será sua atitude?  \
# 0   Vou aceitar e retornar ao modelo 100% presencial
# 1   Vou aceitar e retornar ao modelo 100% presencial
# 2  Vou procurar outra oportunidade no modelo híbr...
# 3  Vou procurar outra oportunidade no modelo híbr...
# 4   Vou aceitar e retornar ao modelo 100% presencial
#
#                Sua empresa passu por Layoff em 2022?  \
# 0  Não ocorreram layoffs/demissões em massa na em...
# 1  Não ocorreram layoffs/demissões em massa na em...
# 2  Não ocorreram layoffs/demissões em massa na em...
# 3  Não ocorreram layoffs/demissões em massa na em...
# 4  Não ocorreram layoffs/demissões em massa na em...
#
#                                              Atuacao  \
# 0                                Engenharia de Dados
# 1                                             Gestor
# 2  desenvolve modelos preditivos e algoritmos de ...
# 3  desenvolve modelos preditivos e algoritmos de ...
# 4                                      Outra atuação
#
#   Quais das linguagens listadas abaixo você utiliza no trabalho? EM_BUSCA  \
# 0                                                SQL                False
# 1                                                NaN                 True
# 2                                                  1                False
# 3                                                  0                False
# 4                                                SQL                False
#
#    ABERTO_OPORTUNIDADES
# 0                 False
# 1                 False
# 2                  True
# 3                  True
# 4                  True
#
# [5 rows x 46 columns]

# %%
dados5["GENERO"].value_counts()
# Out:
# GENERO
# Masculino               3194
# Feminino                1056
# Prefiro não informar      21
# Name: count, dtype: int64

# %%
genero_counts = dados5["GENERO"].value_counts()

# %%
import matplotlib.pyplot as plt

# %%
plt.figure()
plt.bar (height=genero_counts.values, x=genero_counts.index)
plt.title ("Quantidade de pessoas por gênero na área de Dados")
plt.xlabel ("Genero")
plt.ylabel ("Contagem")
plt.show()

# %%
import seaborn as sns

# %%
plt.figure()
sns.countplot (data = dados5, x= "GENERO", palette= "pastel")
plt.title ("Quantidade de pessoas por gênero na área de Dados")
plt.xlabel ("Genero")
plt.ylabel ("Contagem")
plt.grid (True)
plt.show()
# Out:
# /tmp/ipykernel_4514/2023212960.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot (data = dados5, x= "GENERO", palette= "pastel")

# %%
dados5['SALARIO'] = pd.to_numeric(dados5['SALARIO'], errors='coerce')
salario_por_idade = dados5.groupby("IDADE")["SALARIO"].mean()

# %%
salario_por_idade = dados5.groupby("IDADE")["SALARIO"].mean()

# %%
salario_por_idade
# Out:
# IDADE
# 18.0                       1320.142857
# 19.0                       3354.875000
# 20.                        1860.333333
# 20.0                       2938.400000
# 21.0                       3729.639344
# 22.0                       3791.131868
# 23.0                       5278.712000
# 24.0                       5885.259036
# 25.0                       7614.970464
# 26.0                       7709.654618
# 27.0                       8308.212687
# 28.0                       9998.934363
# 29.0                       9637.427273
# 30.0                      10504.407407
# 31.0                      10022.730088
# 31.153.517.220.250.300    10600.309524
# 32.0                      11209.569307
# 33.0                      11857.126582
# 34.0                      12909.736527
# 35.0                      12712.557377
# 36.0                      12658.864662
# 37.0                      12847.471154
# 38.0                      13669.447761
# 39.0                      12845.290698
# 40.0                      15124.851852
# 41.0                      14323.053571
# 42.0                      12994.047619
# 43.0                      14542.558140
# 44.0                      14209.421053
# 45.0                      14956.657143
# 46.0                      12549.000000
# 47.0                      11970.769231
# 48.0                      12736.473684
# 49.0                      14194.333333
# 50.0                      15305.200000
# 51.0                       9316.000000
# 52.0                      13164.133333
# 53.0                      10962.250000
# 54.0                      11718.000000
# Name: SALARIO, dtype: float64

# %%
dados5['IDADE'] = pd.to_numeric(dados5['IDADE'], errors='coerce')
media_17_21 = int(dados5[dados5["FAIXA IDADE"] == "17-21"]["IDADE"].mean())

# %%
media_geral = media_17_21 = int(dados5[dados5["FAIXA IDADE"]== "17-21"]["IDADE"].mean())

# %%
salario_por_idade = dados5.groupby("IDADE")["SALARIO"].mean()

# %%
salario_por_idade
# Out:
# IDADE
# 18.0     1320.142857
# 19.0     3354.875000
# 20.0     2797.782609
# 21.0     3729.639344
# 22.0     3791.131868
# 23.0     5278.712000
# 24.0     5885.259036
# 25.0     7614.970464
# 26.0     7709.654618
# 27.0     8308.212687
# 28.0     9998.934363
# 29.0     9637.427273
# 30.0    10504.407407
# 31.0    10022.730088
# 32.0    11209.569307
# 33.0    11857.126582
# 34.0    12909.736527
# 35.0    12712.557377
# 36.0    12658.864662
# 37.0    12847.471154
# 38.0    13669.447761
# 39.0    12845.290698
# 40.0    15124.851852
# 41.0    14323.053571
# 42.0    12994.047619
# 43.0    14542.558140
# 44.0    14209.421053
# 45.0    14956.657143
# 46.0    12549.000000
# 47.0    11970.769231
# 48.0    12736.473684
# 49.0    14194.333333
# 50.0    15305.200000
# 51.0     9316.000000
# 52.0    13164.133333
# 53.0    10962.250000
# 54.0    11718.000000
# Name: SALARIO, dtype: float64

# %%
plt.figure()
plt.plot(salario_por_idade.index, salario_por_idade.values, marker="o", linestyle="--")
plt.xlabel("IDADE")
plt.ylabel("Media de salario")
plt.title("Media de salario por idade")
plt.grid ("True")
plt.show()

# %%
import plotly.express as px

# %%
fig = px.line (salario_por_idade.reset_index(), x = "IDADE" , y= "SALARIO", title = "Media de salario por idade" , markers=True )
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="194c252c-db95-497c-b860-28c2d681937d" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("194c252c-db95-497c-b860-28c2d681937d")) {                    Plotly.newPlot(                        "194c252c-db95-497c-b860-28c2d681937d",                        [{"hovertemplate":"IDADE=%{x}\u003cbr\u003eSALARIO=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines+markers","name":"","orientation":"v","showlegend":false,"x":[18.0,19.0,20.0,21.0,22.0,23.0,24.0,25.0,26.0,27.0,28.0,29.0,30.0,31.0,32.0,33.0,34.0,35.0,36.0,37.0,38.0,39.0,40.0,41.0,42.0,43.0,44.0,45.0,46.0,47.0,48.0,49.0,50.0,51.0,52.0,53.0,54.0],"xaxis":"x","y":[1320.142857142857,3354.875,2797.782608695652,3729.6393442622953,3791.131868131868,5278.712,5885.259036144578,7614.970464135021,7709.654618473895,8308.212686567163,9998.934362934362,9637.427272727273,10504.407407407407,10022.730088495575,11209.569306930693,11857.12658227848,12909.736526946108,12712.557377049181,12658.864661654135,12847.471153846154,13669.44776119403,12845.290697674418,15124.851851851852,14323.05357142857,12994.047619047618,14542.558139534884,14209.421052631578,14956.657142857142,12549.0,11970.76923076923,12736.473684210527,14194.333333333334,15305.2,9316.0,13164.133333333333,10962.25,11718.0],"yaxis":"y","type":"scatter"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576 ...

# %%
plt.figure(figsize= (15,5))
plt.scatter(dados5["IDADE"], dados5["SALARIO"], alpha=0.5)
plt.xlabel("IDADE")
plt.ylabel("Media de salario")
plt.title("Dispersão de salário por idade")
plt.grid ("True")
plt.show()

# %%
fig =px.scatter (dados5, x= "IDADE" , y= "SALARIO", title="Dispersão de salário por idade")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="cfb101c1-0e9b-4c7f-bb4d-56b9474a724e" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("cfb101c1-0e9b-4c7f-bb4d-56b9474a724e")) {                    Plotly.newPlot(                        "cfb101c1-0e9b-4c7f-bb4d-56b9474a724e",                        [{"hovertemplate":"IDADE=%{x}\u003cbr\u003eSALARIO=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers","name":"","showlegend":false,"x":[39.0,32.0,53.0,27.0,46.0,32.0,21.0,31.0,33.0,31.0,25.0,33.0,31.0,24.0,35.0,28.0,31.0,29.0,28.0,26.0,37.0,33.0,26.0,46.0,34.0,27.0,25.0,27.0,24.0,25.0,26.0,27.0,29.0,33.0,24.0,25.0,27.0,26.0,31.0,32.0,40.0,29.0,35.0,32.0,18.0,29.0,24.0,24.0,46.0,29.0,30.0,37.0,28.0,40.0,28.0,30.0,34.0,33.0,28.0,34.0,31.0,30.0,39.0,26.0,39.0,31.0,null,38.0,48.0,28.0,27.0,26.0,33.0,28.0,39.0,31.0,25.0,43.0,35.0,44.0,31.0,43.0,34.0,32.0,48.0,29.0,33.0,33.0,26.0,50.0,28.0,22.0,31.0,37.0,30.0,36.0,null,40.0,51.0,27.0,29.0,32.0,29.0,24.0,31.0,26.0,31.0,44.0,28.0,33.0,39.0,25.0,28.0,31.0,20.0,25.0,24.0,30.0,27.0,26.0,22.0,null,32.0,37.0,31.0,27.0,31.0,27.0,33.0,23.0,22.0,42.0,25.0,26.0,34.0,36.0,21.0,29.0,29.0,27.0,25.0,30.0,25.0,29.0,24.0,24.0,31.0,36.0,31.0,33.0,47.0,22.0,26.0,26.0,39.0,30.0,null,31.0,41.0,37.0,26.0,32.0,null,28.0,24.0,32.0,34.0,44.0,26.0,31.0,34.0,41.0,31.0,39.0,29.0,36.0,22.0,28.0,29.0,31.0,26.0,32.0,25.0,33.0,33.0,29.0,25.0,33.0,24.0,34.0,32.0,46.0,34.0,42.0,21.0,32.0,36.0,39.0,41.0,31.0,35.0,29.0,26.0,24.0,29.0,21.0,33.0,29.0,30.0,32.0,26.0,34.0,34.0,20.0,22.0,45.0,24.0,26.0,26.0,27.0,34.0,31.0,50.0,27.0,34.0,23.0,45.0,33.0,21.0,30.0,26.0,35.0,27.0,31.0,30.0,40.0,24.0,32.0,31.0,34.0,22.0,29.0,36.0,44.0,22.0,29.0,18.0,30.0,28.0,26.0,27.0,24.0,31.0,24.0,31.0,33.0,21.0,30.0,30.0,33.0,34.0,27.0,26.0,28.0,31.0,33.0,37.0,28.0,50.0,31.0,25.0,30.0,33.0,36.0,31.0,22.0,25.0,42.0,27.0,26.0,30.0,24.0,29.0,26.0,29.0,37.0,31.0,29.0,25.0,27.0,29.0,42.0,32.0,45.0,38.0,41.0,26.0,null,28.0,23.0,25.0,38.0,32.0,35.0,24.0,25.0,32.0,33.0,24.0,28.0,24.0,31.0,34.0,38.0,43.0,50.0,22.0,33.0,26.0,28.0,38.0,45.0,32.0,22.0,30.0,31.0,31.0,34.0,25.0,32.0,35.0,36.0,34.0,36.0,35.0,54.0,37.0,44.0,40.0,25.0,23.0,38.0,31.0,29.0,38.0,41.0,32.0,30.0,22.0,26.0,25.0,32.0,29.0,32.0,41.0,25.0,28.0,25.0,37.0,35.0,29.0,22.0,25.0,32.0,35.0,29.0,34.0,31.0,45.0,34.0,27.0,25.0,26.0,23.0,26.0,49.0,49.0,37.0,35.0,37.0,39.0,21.0,32.0,46.0,null,26.0,41.0,45.0,32.0,36.0,26.0,22.0,28.0,29.0,35.0,25.0,32.0,48.0,33.0,35.0,27.0,37.0,32.0,38.0,54.0,39.0,43.0,35.0,31.0,23.0,41.0,23.0,37.0,54.0,31.0,29.0,27.0,35.0,22.0,20.0,45.0,33.0,39.0,27.0,28.0,null,26.0,null,26.0,27.0,27.0,49.0,52.0,34.0,40.0,32.0,28.0,39.0,33.0,47.0,46.0,25.0,26.0,45.0,22.0,31.0,44.0,27.0,30.0,37.0,29.0,20.0,26.0,37.0,18.0,30.0,29.0,37.0,32.0,27.0,37.0,27.0,42.0,32.0,28.0,28.0,29.0,29.0,39.0,22.0,30.0,30.0,32.0,30.0,29.0,28.0,42.0,null,29.0,35.0,35.0,28.0,27.0,26.0,22.0,32.0,31.0,26.0,32.0,38.0,31.0,34.0,43.0,24.0,22.0,29.0,32.0,39.0,34.0,26.0,28.0,34.0,29.0,23.0,31.0,26.0,29.0,52.0,22.0,29.0,30.0,24.0,21.0,44.0,39.0,25.0,26.0,23.0,30.0,40.0,21.0,34.0,31.0,25.0,30.0,44.0,30.0,30.0,36.0,39.0,28.0,34.0,39.0,27.0,33.0,34.0,37.0,23.0,29.0,32.0,24.0,35.0,23.0,25.0,36.0,36.0,28.0,29.0,31.0,26.0,36.0,27.0,32.0,31.0,31.0,41.0,31.0,27.0,32.0,27.0,23.0,31.0,29.0,32.0,25.0,31.0,25.0,37.0,32.0,23.0,25.0,52.0,30.0,29.0,23.0,29.0,null,27.0,51.0,46.0,31.0,35.0,25.0,36.0,33.0,25.0,19.0,43.0,24.0,23.0,43.0,36.0,30.0,38.0,36.0,25.0,24.0,22.0,44.0,48.0,37.0,48.0,33.0,40.0,34.0,28.0,25.0,26.0,32.0,54.0,43.0,32.0,29.0,36.0,35.0,34.0,34.0,21.0,25.0,23.0,20.0,49.0,30.0,27.0,36.0,28.0,26.0,24.0,36.0,32.0,28.0,34.0,44.0,43.0,36.0,30.0,42.0,31.0,27.0,39.0,37.0,39.0,21.0,42.0,30.0, ...
